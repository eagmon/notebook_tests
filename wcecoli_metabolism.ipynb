# %%
import pandas as pd
import json

def safe_parse_json(json_str):
    try:
        return json.loads(json_str.replace("'", '"'))
    except json.JSONDecodeError:
        return None  # or some default value or handling

# %% [markdown]
# ## load data

# %%
metabolic_reactions = pd.read_csv('data/metabolic_reactions.tsv', sep='\t', comment='#')
complexation_reactions = pd.read_csv('data/complexation_reactions.tsv', sep='\t', comment='#')
genes = pd.read_csv('data/genes.tsv', sep='\t', comment='#')
transcripts = pd.read_csv('data/rnas.tsv', sep='\t', comment='#')

# Convert the 'catalyzed_by' column from string representations of lists to actual lists
metabolic_reactions['catalyzed_by'] = metabolic_reactions['catalyzed_by'].apply(safe_parse_json)
complexation_reactions['stoichiometry'] = complexation_reactions['stoichiometry'].apply(safe_parse_json)
transcripts['monomer_ids'] = transcripts['monomer_ids'].apply(safe_parse_json)

# %%
print('METABOLISM')
print(metabolic_reactions.info())
print('\nCOMPLEXATION')
print(complexation_reactions.info())
print('\nGENES')
print(genes.info())
print('\nTRANSCRIPTS')
print(transcripts.info())
# Out:
# METABOLISM
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6590 entries, 0 to 6589
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             6590 non-null   object
#  1   stoichiometry  6590 non-null   object
#  2   direction      6590 non-null   object
#  3   catalyzed_by   6590 non-null   object
# dtypes: object(4)
# memory usage: 206.1+ KB
# None
#
# COMPLEXATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1135 entries, 0 to 1134
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1135 non-null   object
#  1   stoichiometry  1135 non-null   object
#  2   common_name    904 non-null    object
#  3   cofactors      1135 non-null   object
# dtypes: object(4)
# memory usage: 35.6+ KB
# None
#
# GENES
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4748 entries, 0 to 4747
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             4748 non-null   object
#  1   symbol         4722 non-null   object
#  2   synonyms       4748 non-null   object
#  3   left_end_pos   4726 non-null   float64
#  4   right_end_pos  4726 non-null   float64
#  5   direction      4744 non-null   object
#  6   rna_ids        4748 non-null   object
# dtypes: float64(2), object(5)
# memory usage: 259.8+ KB
# None
#
# TRANSCRIPTS
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4748 entries, 0 to 4747
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               4748 non-null   object
#  1   common_name      4722 non-null   object
#  2   synonyms         4748 non-null   object
#  3   type             4748 non-null   object
#  4   modified_forms   4748 non-null   object
#  5   gene_id          4748 non-null   object
#  6   monomer_ids      4748 non-null   object
#  7   anticodon        86 non-null     object
#  8   coding_segments  4748 non-null   object
# dtypes: object(9)
# memory usage: 334.0+ KB
# None

# %% [markdown]
# ## analyze metabolism

# %%
# Flatten the list of lists into a single list
all_enzymes = [enzyme for sublist in metabolic_reactions['catalyzed_by'] for enzyme in sublist]

# Extract unique enzymes
unique_enzymes = list(set(all_enzymes))

len(unique_enzymes)
# Out:
# 1563

# %%
print(unique_enzymes)
# Out:
# ['CPLX-7524', 'CPLX0-8200', 'G6653-MONOMER', 'URACIL-PRIBOSYLTRANS-CPLX', 'CPLX0-254', 'CPLX0-8010', 'G7103-MONOMER', 'CPLX0-3021', 'PDXK-CPLX', 'EG12267-MONOMER', 'ISOCIT-LYASE', 'DIHYDROFOLATEREDUCT-MONOMER', 'EG11846-MONOMER', 'CPLX0-7997', 'CPLX0-8122', 'G6474-MONOMER', 'EG11486-MONOMER', 'ABC-49-CPLX', 'YFEP-MONOMER', 'EG11921-MONOMER', 'FABZ-CPLX', 'CPLX0-7992', 'DIHYDROXYACIDDEHYDRAT-CPLX', 'PSERPHOSPHA-MONOMER', 'FGAMSYN-MONOMER', 'CPLX0-322', 'BIOTIN-CARBOXYL-CPLX', 'CPLX0-8614', 'CPLX0-8032', 'CPLX0-301', 'G7800-MONOMER', 'G7410-MONOMER', 'CPLX0-7652', 'EG11383-MONOMER', 'YHHO-MONOMER', 'O-SUCCINYLBENZOATE-COA-SYN-MONOMER', 'UDP-NACMURALGLDAPAALIG-MONOMER', 'EG10119-MONOMER', 'CPLX0-8167', 'CADB-MONOMER', 'CPLX0-7974', 'EG11080-MONOMER', 'EG11938-MONOMER', 'MONOMER0-1241', 'CPLX0-245', 'CPLX0-8112', 'G6532-MONOMER', 'EG11932-MONOMER', 'UDPNACETYLGLUCOSAMENOLPYRTRANS-MONOMER', 'METHGLYSYN-CPLX', 'G6892-MONOMER', 'EG10853-MONOMER', 'G7106-MONOMER', 'G7449-MONOMER', 'CPLX0-3950', 'YBDA-MONOMER', 'PGPPHOSPHAA-MONOMER', 'COBALADENOSYLTRANS-MONOMER', 'AROF-CPLX', 'ABC-14-CPLX', 'ACETOLACTSYNII-CPLX', 'CPLX0-682', 'E2P-MONOMER', 'CPLX-722', 'EG10850-MONOMER', 'CPLX0-7760', 'DIHYDROOROT-CPLX', 'CPLX0-1261', 'EG10942-MONOMER', 'CMR-MONOMER', 'NADPPHOSPHAT-MONOMER', 'MONOMER0-2798', 'PHOSACETYLTRANS-CPLX', 'CPLX0-3861', 'YJGT-MONOMER', 'CPLX0-231', 'AROK-MONOMER', 'OHMETHYLBILANESYN-MONOMER', 'ADHC-CPLX', 'YIDY-MONOMER', 'G7138-MONOMER', 'G7504-MONOMER', 'MALTACETYLTRAN-CPLX', 'CPLX0-7533', 'CPLX0-8263', 'ABC-56-CPLX', 'XASA-MONOMER', 'DCYSDESULF-CPLX', 'EG11983-MONOMER', 'CYTIDEAM-CPLX', 'EG12357-MONOMER', 'CPLX0-8187', 'EG11736-MONOMER', 'EG11581-MONOMER', 'ENVZ-CPLX', 'G7319-MONOMER', '7-ALPHA-HYDROXYSTEROID-DEH-CPLX', 'MTR-MONOMER', '3-ISOPROPYLMALDEHYDROG-CPLX', 'LYSDECARBOX-CPLX', 'CPLX0-7936', 'YDEA-MONOMER', 'CPLX0-1924', 'EG11362-MONOMER', 'CPLX0-8535', 'G7063-MONOMER', 'EG12115-MONOMER', 'SULFATE-ADENYLYLTRANS-CPLX', 'DCUC-MONOMER', 'CHER-MONOMER', 'CPLX0-7950', 'CPLX0-8238', 'EG11671-MONOMER', 'GNTT-MONOMER', 'ABC-58-CPLX', 'ADENPRIBOSYLTRAN-CPLX', 'BETAGALACTOSID-CPLX', 'CPLX0-8251', 'EG10168-MONOMER', 'EG10484-MONOMER', '1-PFK', 'THYMIDYLATESYN-CPLX', 'G7919-MONOMER', 'CPLX0-7530', 'G6287-MONOMER', 'PSERTRANSAM-CPLX', 'CPLX0-7631', 'EG11955-MONOMER', 'CPLX0-7947', 'G6208-MONOMER', 'ERYTH4PDEHYDROG-CPLX', 'SAMDECARB-CPLX', 'G7634-MONOMER', 'EG10548-MONOMER', 'NACGLCTRANS-MONOMER', 'KDUD-MONOMER', 'TNAB-MONOMER', 'LDC2-CPLX', 'EG11600-MONOMER', 'CPLX0-321', 'EG10626-MONOMER', 'LCTP-MONOMER', 'EG11512-MONOMER', 'HISS-CPLX', 'CPLX0-7808', 'HISTDEHYD-CPLX', 'CPLX0-7653', 'CPLX0-7662', 'CPLX0-2161', 'EG11551-MONOMER', 'CPLX0-3104', 'CPLX0-237', 'EG11662-MONOMER', 'YIDT-MONOMER', 'CARDIOLIPSYN-MONOMER', 'G6934-MONOMER', 'CPLX-158', 'EG11646-MONOMER', 'EG10003-MONOMER', 'MHPF-MONOMER', 'CPLX0-7646', 'DIHYDROOROTOX-MONOMER', 'G6190-MONOMER', 'EG11426-MONOMER', 'EG10486-MONOMER', 'UHPT-MONOMER', 'EG11829-MONOMER', 'G495-MONOMER', 'EG10487-MONOMER', 'G6805-MONOMER', 'CPLX0-341', 'EG12450-MONOMER', 'G6986-MONOMER', 'CDPDIGLYSYN-MONOMER', 'EG11579-MONOMER', 'CPLX0-3721', 'AMYLOMALT-MONOMER', 'CPLX0-8128', '6PGLUCONOLACT-MONOMER', 'LSERINEDEAM1-MONOMER', 'CPLX0-721', 'DSBG-CPLX', 'PROPKIN-MONOMER', 'ANSB-CPLX', 'PKII-CPLX', 'EG11292-MONOMER', 'SPERMACTRAN-CPLX', 'CPLX0-7889', 'GABATRANSAM-CPLX', 'NICONUCADENYLYLTRAN-MONOMER', 'GLYCEROL-3-P-ACYLTRANSFER-MONOMER', 'ABC-8-CPLX', 'ADENYL-KIN-MONOMER', 'G7324-MONOMER', 'CPLX0-7904', 'G6260-MONOMER', 'NUPG-MONOMER', 'G7860-MONOMER', 'YDGEF-CPLX', 'EG11665-MONOMER', 'L-GLN-FRUCT-6-P-AMINOTRANS-CPLX', 'G7166-MONOMER', 'G6924-MONOMER', 'EG11309-MONOMER', 'DCUA-MONOMER', 'CPLX0-3934', 'CPLX0-7', 'EG12069-MONOMER', 'TRANS-CPLX-203', 'PROS-CPLX', 'CPDB-MONOMER', 'TRYPTOPHAN-CPLX', 'CPLX0-224', 'CPLX0-7887', 'CPLX0-3954', 'KGTP-MONOMER', 'YHFM-MONOMER', 'RPOA-MONOMER', 'CPLX0-1943', 'PRAI-IGPS', 'G7098-MONOMER', 'DIACYLGLYKIN-CPLX', 'CPLX0-2641', 'DIHYDRODIPICSYN-CPLX', 'PYRDAMPTRANS-MONOME ...

# %% [markdown]
# ## analyze complexation

# %%
# Initialize a dictionary to hold the mapping of complexes to their components
complex_to_components = {}

# Iterate over each row in the DataFrame
for index, row in complexation_reactions.iterrows():
    stoichiometry = row['stoichiometry']
    # Iterate over each item in the stoichiometry dictionary
    for component, count in stoichiometry.items():
        # Skip if count is None or not an integer
        if count is None or not isinstance(count, int):
            continue
        # If the count is positive, it's a complex; if negative, it's a component
        if count > 0:
            # Initialize the complex in the dictionary if not already present
            if component not in complex_to_components:
                complex_to_components[component] = []
            # Add the components (with negative counts) to the complex's list
            complex_to_components[component].extend([comp for comp, comp_count in stoichiometry.items() if comp_count is not None and comp_count < 0])

# print the mapping
for complex, components in complex_to_components.items():
    print(f"{complex}: {components}")
# Out:
# 1-PFK: ['1-PFK-MONOMER']
# 2OXOGLUTARATEDEH-CPLX: ['E1O', 'E2O', 'E3-CPLX']
# 3-ISOPROPYLMALDEHYDROG-CPLX: ['3-ISOPROPYLMALDEHYDROG-MONOMER']
# 3-ISOPROPYLMALISOM-CPLX: ['LEUC-MONOMER', 'LEUD-MONOMER']
# 3-METHYL-2-OXOBUT-OHCH3XFER-CPLX: ['3-CH3-2-OXOBUTANOATE-OH-CH3-XFER-MONOMER']
# 3-OXOACYL-ACP-SYNTHII-CPLX: ['3-OXOACYL-ACP-SYNTHII-MONOMER']
# 6PFK-1-CPX: ['6PFK-1-MONOMER']
# 6PFK-2-CPX: ['6PFK-2-MONOMER']
# 6PGLUCONDEHYDROG-CPLX: ['6PGLUCONDEHYDROG-MONOMER']
# 7-ALPHA-HYDROXYSTEROID-DEH-CPLX: ['7-ALPHA-HYDROXYSTEROID-DEH-MONOMER']
# 7KAPSYN-CPLX: ['7KAPSYN-MONOMER']
# ABC-10-CPLX: ['FEPC-MONOMER', 'FEPD-MONOMER', 'FEPG-MONOMER', 'FEPB-MONOMER']
# ABC-11-CPLX: ['FHUC-MONOMER', 'FHUB-MONOMER', 'FHUD-MONOMER']
# ABC-12-CPLX: ['GLNQ-MONOMER', 'GLNP-MONOMER', 'GLNH-MONOMER']
# ABC-13-CPLX: ['G6359-MONOMER', 'GLTK-MONOMER', 'GLTJ-MONOMER', 'GLTL-MONOMER']
# ABC-14-CPLX: ['HISP-MONOMER', 'HISM-MONOMER', 'HISQ-MONOMER', 'HISJ-MONOMER']
# ABC-15-CPLX: ['LIVF-MONOMER', 'LIVG-MONOMER', 'LIVH-MONOMER', 'LIVM-MONOMER', 'LIVJ-MONOMER']
# ABC-16-CPLX: ['MALK-MONOMER', 'MALF-MONOMER', 'MALG-MONOMER', 'MALE-MONOMER']
# ABC-18-CPLX: ['MGLA-MONOMER', 'MGLC-MONOMER', 'MGLB-MONOMER']
# ABC-19-CPLX: ['MODC-MONOMER', 'MODB-MONOMER', 'MODA-MONOMER']
# ABC-2-CPLX: ['ARAG-MONOMER', 'ARAH-MONOMER', 'ARAF-MONOMER']
# ABC-20-CPLX: ['NIKD-MONOMER', 'NIKE-MONOMER', 'NIKB-MONOMER', 'NIKC-MONOMER', 'NIKA-MONOMER']
# ABC-21-CPLX: ['YADG-MONOMER', 'YADH-MONOMER']
# ABC-22-CPLX: ['OPPC-MONOMER', 'OPPD-MONOMER', 'OPPF-MONOMER', 'OPPB-MONOMER', 'OPPA-MONOMER']
# ABC-23-CPLX: ['PHNC-MONOMER', 'PHNE-MONOMER', 'PHND-MONOMER']
# ABC-24-CPLX: ['POTA-MONOMER', 'POTB-MONOMER', 'POTC-MONOMER', 'POTD-MONOMER']
# ABC-25-CPLX: ['POTG-MONOMER', 'POTH-MONOMER', 'POTI-MONOMER', 'POTF-MONOMER']
# ABC-26-CPLX: ['PROV-MONOMER', 'PROW-MONOMER', 'PROX-MONOMER']
# ABC-27-CPLX: ['PSTB-MONOMER', 'PSTA-MONOMER', 'PSTC-MONOMER', 'PSTS-MONOMER']
# ABC-28-CPLX: ['RBSA-MONOMER', 'RBSC-MONOMER', 'RBSB-MONOMER']
# ABC-29-CPLX: ['SAPF-MONOMER', 'SAPC-MONOMER', 'SAPB-MONOMER', 'SAPD-MONOMER']
# ABC-3-CPLX: ['HISQ-MONOMER', 'HISP-MONOMER', 'HISM-MONOMER', 'ARGT-MONOMER']
# ABC-304-CPLX: ['LIVK-MONOMER', 'LIVM-MONOMER', 'LIVH-MONOMER', 'LIVG-MONOMER', 'LIVF-MONOMER']
# ABC-32-CPLX: ['SFUC-MONOMER', 'SFUB-MONOMER', 'SFUA-MONOMER']
# ABC-33-CPLX: ['XYLG-MONOMER', 'XYLH-MONOMER', 'XYLF-MONOMER']
# ABC-34-CPLX: ['UGPC-MONOMER', 'UGPA-MONOMER', 'UGPE-MONOMER', 'UGPB-MONOMER']
# ABC-35-CPLX: ['CCMC-MONOMER', 'EG12169-MONOMER', 'CCME-MONOMER']
# ABC-4-CPLX: ['ARTJ-MONOMER', 'ARTQ-MONOMER', 'ARTM-MONOMER', 'ARTP-MONOMER']
# ABC-40-CPLX: []
# ABC-41-CPLX: ['YEJF-MONOMER', 'YEJB-MONOMER', 'YEJE-MONOMER', 'YEJA-MONOMER']
# ABC-42-CPLX: ['YJCW-MONOMER', 'YJCV-MONOMER', 'YJCX-MONOMER']
# ABC-45-CPLX: ['G7658-MONOMER', 'EG12799-MONOMER', 'YRBE-MONOMER', 'YRBF-MONOMER']
# ABC-46-CPLX: ['YJFF-MONOMER', 'YTFR-MONOMER', 'YTFT-MONOMER', 'YTFQ-MONOMER']
# ABC-48-CPLX: []
# ABC-49-CPLX: ['YLIA-MONOMER', 'YLIB-MONOMER', 'YLID-MONOMER', 'YLIC-MONOMER']
# ABC-5-CPLX: ['BTUD-MONOMER', 'BTUC-MONOMER', 'EG12334-MONOMER']
# ABC-51-CPLX: ['YDCS-MONOMER', 'YDCT-MONOMER', 'YDCV-MONOMER', 'YDCU-MONOMER']
# ABC-52-CPLX: ['YHDZ-MONOMER', 'YHDY-MONOMER', 'YHDX-MONOMER', 'YHDW-MONOMER']
# ABC-54-CPLX: ['FTSE-MONOMER', 'FTSX-MONOMER']
# ABC-55-CPLX: ['YCJP-MONOMER', 'YCJO-MONOMER', 'YCJN-MONOMER', 'YCJV-MONOMER']
# ABC-56-CPLX: ['G6478-MONOMER', 'YCBM-MONOMER', 'YCBE-MONOMER']
# ABC-57-CPLX: ['YBHS-MONOMER', 'YBHR-MONOMER', 'YBHF-MONOMER']
# ABC-58-CPLX: ['YNEA-MONOMER', 'YDEZ-MONOMER', 'YDEY-MONOMER', 'YDEX-MONOMER']
# ABC-59-CPLX: ['YDDR-MONOMER', 'YDDQ-MONOMER', 'YDDS-MONOMER', 'YDDP-MONOMER', 'YDDO-MONOMER']
# ABC-6-CPLX: ['CYDD-MONOMER', 'CYDC-MONOMER']
# ABC-60-CPLX: []
# ABC-61-CPLX: ['YBBP-MONOMER', 'YBBA-MONOMER']
# ABC-62-CPLX: ['YCFW-MONOMER', 'YCFV-MONOMER', 'YCFU-MONOMER']
# ABC-63-CPLX: ['ZNUC-MONOMER', 'ZNUB-MONOMER', 'ZNUA-MONOMER']
# ABC-64-CPLX: ['TAUA-MONOMER', 'TAUC-MONOMER', 'TAUB-MONOMER']
# ABC-7-CPLX: ['CYSA-MONOMER', 'CYSW-MONOMER', 'CYST-MONOMER', 'CYSP-MONOMER']
# ABC-70-CPLX: ['SBP-MONOMER', 'CYSW-MONOMER', 'CYST-MONOMER', 'CYSA-MONOMER']
# ABC-8-CPLX: ['DPPD-MONOMER', 'DPPF-MONOMER', 'DPPB-MONOMER', 'DPPC-MONOMER', 'DPPA-MONOMER']
# ABC-9-CPLX: ['FECE-MONOMER', 'FECC-MONOMER', 'FECD-MONOMER', 'FECB-MONOMER']
# ACETOACETYL-COA-TRANSFER-CPLX: ['ATOA-CPLX', 'ATOD-CPLX']
# ACETOLACTSYNI-CPLX: ['LARGEILVB-MONOMER', 'SMALLILVN-MONOMER']
# ACETOLACTSYNII-CPLX: []
# ACETOLACTSYNIII-CPLX: ['ACETOLACTSYNIII-ICHAIN-MONOMER', 'ACETOLACTSYNIII-HCHAIN-MONOMER']
# ACETYL-COA-ACETYLTRANSFER-CPLX: ['ACETYL-COA-ACETYLTRANSFER-MONOMER']
# ACETYL-COA-CARBOXYLMULTI-CPLX: ['ACETYL-COA-CARBOXYLTRANSFER-CPLX', 'BIOTIN-CARBOXYL-CPLX', 'BCCP-CPLX']
# ACETYL-COA-CARBOXYLTRANSFER-CPLX: ['CARBOXYL-TRANSFERASE-ALPHA-MONOMER', 'CARBOXYL-TRANSFERASE-BETA-MONOMER']
# ACETYLGLUTKIN-CPLX: ['ACETYLGLUTKIN-MONOMER']
# ACETYLORNDEACET-CPLX: ['ACETYLORNDEACET-MONOMER']
# ACETYLORNTRANSAM-CPLX: ['ACETYLORNTRANSAM-MONOMER']
# ACNEULY-CPLX: ['ACNEULY-MONOMER']
# ACSERLYA-CPLX: ['ACSERLYA-MONOMER']
# ACSERLYB-CPLX: ['ACSERLYB-MONOMER']
# ACYLCOASYN-CPLX: ['ACYLCOASYN-MONOMER']
# ADCLY-CPLX: ['ADCLY-MONOMER']
# ADENPRIBOSYLTRAN-CPLX: ['ADENPRIBOSYLTRAN-MONOMER']
# ADENYLOSUCCINATE-SYN-DIMER: ['ADENYLOSUCCINATE-SYN-MONOMER']
# ADENYLYLSULFKIN-CPLX: ['ADENYLYLSULFKIN-MONOMER']
# ADHC-CPLX: ['ADHC-MONOMER']
# ADHE-CPLX: ['ADHE-MONOMER']
# AERGLYC3PDEHYDROG-CPLX: ['AERGLYC3PDEHYDROG-MONOMER']
# AGMATIN-CPLX: ['AGMATIN-MONOMER']
# AIRS-CPLX: ['AIRS-MONOMER']
# AKBLIG-CPLX: ['AKBLIG-MONOMER']
# ALAS-CPLX: ['ALAS-MONOMER']
# ALD-CPLX: ['LACTALDDEHYDROG-MONOMER']
# ALKAPHOSPHA-CPLX: ['ALKAPHOSPHA-MONOMER']
# ALPHA-SUBUNIT-CPLX: ['FDNI-MONOMER', 'FDNH-MONOMER', 'FDNG-MONOMER']
# ALPHAGALACTOSID-CPLX: ['ALPHAGALACTOSID-MONOMER']
# AMINEOXID-CPLX: ['AMINEOXID-MONOMER']
# AMP-NUCLEOSID-CPLX: ['AMP-NUCLEOSID-MONOMER']
# ANGLYC3PDEHYDROG-CPLX: ['ANGLYC3PDEHYDROGSUBUNITA-MONOMER', 'ANGLYC3PDEHYDROGSUBUNITB-MONOMER', 'ANGLYC3PDEHYDROGSUBUNITC-MONOMER']
# ANSA-CPLX: ['ANSA-MONOMER']
# ANSB-CPLX: ['ANSB-MONOMER']
# ANTHRANSYN-CPLX: ['ANTHRANSYNCOMPI-MONOMER', 'ANTHRANSYNCOMPII-MONOMER']
# APHA-CPLX: ['APHA-MONOMER']
# APORNAP-CPLX: ['EG10893-MONOMER', 'RPOC-MONOMER', 'RPOB-MONOMER']
# APP-UBIOX-CPLX: ['APPC-MONOMER', 'APPB-MONOMER', 'MONOMER0-2817']
# ARABISOM-CPLX: ['ARABISOM-MONOMER']
# ARGDECARBOXBIO-CPLX: ['ARGDECARBOXBIO-MONOMER']
# ARGDECARBOXDEG-CPLX: ['ARGDECARBOXDEG-MONOMER']
# AROC-CPLX: ['AROC-MONOMER']
# AROD-CPLX: ['AROD-MONOMER']
# AROF-CPLX: ['AROF-MONOMER']
# AROG-CPLX: ['AROG-MONOMER']
# AROH-CPLX: ['AROH-MONOMER']
# ASNS-CPLX: ['ASNS-MONOMER']
# ASNSYNA-CPLX: ['ASNSYNA-MONOMER']
# ASNSYNB-CPLX: ['ASNSYNB-MONOMER']
# ASP-SEMIALDEHYDE-DEHYDROGENASE-CPLX: ['ASP-SEMIALDEHYDE-DEHYDROGENASE-MONOMER']
# ASPAMINOTRANS-DIMER: ['ASPAMINOTRANS-MONOMER']
# ASPARTASE-CPLX: ['ASPARTASE-MONOMER']
# ASPCARBCAT-TRIMER: ['ASPCARBCAT-MONOMER']
# ASPCARBREG-DIMER: ['ASPCARBREG-MONOMER']
# ASPCARBTRANS-CPLX: ['ASPCARBCAT-TRIMER', 'ASPCARBREG-DIMER']
# ASPKINIHOMOSERDEHYDROGI-CPLX: ['ASPKINIHOMOSERDEHYDROGI-MONOMER']
# ASPKINIIHOMOSERDEHYDROGII-CPLX: ['ASPKINIIHOMOSERDEHYDROGII-MONOMER']
# ASPKINIII-CPLX: ['ASPKINIII-MONOMER']
# ASPS-CPLX: ['ASPS-MONOMER']
# ATOA-CPLX: ['ATOA-MONOMER']
# ATOD-CPLX: ['ATOD-MONOMER']
# ATPA-CPLX: ['ATPA-MONOMER']
# ATPASE-1-CPLX: ['MONOMER0-12', 'EG10513-MONOMER', 'KDPB-MONOMER', 'EG10515-MONOMER']
# ATPD-CPLX: ['ATPD-MONOMER']
# ATPE-CPLX: ['ATPE-MONOMER']
# ATPF-CPLX: ['ATPF-MONOMER']
# ATPSYN-CPLX: ['F-O-CPLX', 'F-1-CPLX']
# B1-CPLX: ['NRDA-MONOMER']
# B2-CPLX: ['NRDB-MONOMER']
# BADH-CPLX: ['BADH-MONOMER']
# BCCP-CPLX: ['BCCP-BIOTIN']
# BETAGALACTOSID-CPLX: ['BETAGALACTOSID-MONOMER']
# BIOTIN-CARBOXYL-CPLX: ['BIOTIN-CARBOXYL-MONOMER']
# BIOTIN-SYN-CPLX: ['BIOTIN-SYN-MONOMER']
# BRANCHED-CHAINAMINOTRANSFER-CPLX: ['BRANCHED-CHAINAMINOTRANSFER-MONOMER']
# CARBODEHYDRAT-CPLX: ['CARBODEHYDRAT-MONOMER']
# CARBPSYN-CPLX: ['CARBPSYN-LARGE', 'CARBPSYN-SMALL']
# CARNDEHYDRA-CPLX: ['CARNDEHYDRA-MONOMER']
# CFA-CPLX: ['CFA-MONOMER']
# CHEZ-CPLX: ['CHEZ-MONOMER']
# CHORISMUTPREPHENDEHYDRAT-CPLX: ['CHORISMUTPREPHENDEHYDRAT-MONOMER']
# CHORISMUTPREPHENDEHYDROG-CPLX: ['CHORISMUTPREPHENDEHYDROG-MONOMER']
# CITLY-CPLX: ['ACPSUB-CPLX', 'CITTRANS-CPLX', 'CITRYLY-CPLX']
# CITRATE-SI-SYNTHASE: ['CITSYN-MONOMER']
# CITRYLY-CPLX: ['CITRYLY-MONOMER']
# CITTRANS-CPLX: ['CITTRANS-MONOMER']
# COADTRI-CPLX: ['PANTEPADENYLYLTRAN-MONOMER']
# COBU-CPLX: ['COBU-MONOMER']
# CPLX-153: ['ASCF-MONOMER']
# CPLX-154: ['BGLF-MONOMER']
# CPLX-155: ['CELC-MONOMER', 'CELB-MONOMER', 'CELA-MONOMER']
# CPLX-156: ['CMTB-MONOMER', 'CMTA-MONOMER']
# CPLX-157: ['PTSG-MONOMER', 'CRR-MONOMER']
# CPLX-158: ['FRUB-MONOMER', 'FRUA-MONOMER']
# CPLX-159: ['FRVB-MONOMER', 'FRVA-MONOMER']
# CPLX-160: ['FRWC-MONOMER', 'FRWB-MONOMER', 'EG11912-MONOMER', 'EG11906-MONOMER']
# CPLX-165: ['MANZ-MONOMER', 'MANY-MONOMER', 'MANX-MONOMER']
# CPLX-166: ['MTLA-MONOMER']
# CPLX-167: ['NAGE-MONOMER']
# CPLX-168: ['TREB-MONOMER', 'CRR-MONOMER']
# CPLX-169: ['G8210-MONOMER', 'GUTB-MONOMER', 'GUTA-MONOMER']
# CPLX-170: ['AGAB-MONOMER', 'AGAC-MONOMER', 'AGAD-MONOMER']
# CPLX-171: ['G6277-MONOMER']
# CPLX-3942: ['G7712-MONOMER', 'G7713-MONOMER', 'G7714-MONOMER']
# CPLX-3945: ['G6544-MONOMER', 'G6543-MONOMER']
# CPLX-3946: ['EG11072-MONOMER', 'EG11098-MONOMER']
# CPLX-64: ['G6281-MONOMER']
# CPLX-722: ['APPA-MONOMER']
# CPLX-7524: ['G6285-MONOMER']
# CPLX-7: ['ARSF-MONOMER']
# CPLX-8331: ['EG11666-MONOMER']
# CPLX-8401: ['G7463-MONOMER']
# CPLX-9493: ['CCMB-MONOMER', 'CCMA-MONOMER']
# CPLX-9494: ['EG12052-MONOMER', 'EG12054-MONOMER']
# CPLX-9495: ['EG12169-MONOMER', 'CCMC-MONOMER', 'CCMB-MONOMER', 'CCMA-MONOMER']
# CPLX0-0: ['EG10244-MONOMER']
# CPLX0-10157: ['G7716-MONOMER']
# CPLX0-1021: ['G6196-MONOMER']
# CPLX0-10307: ['PHNK-MONOMER']
# CPLX0-10308: ['PHNL-MONOMER']
# CPLX0-10309: ['CPLX0-7935']
# CPLX0-10342: ['G7313-MONOMER', 'CPLX0-3761']
# CPLX0-10367: []
# CPLX0-10380: ['G6487-MONOMER']
# CPLX0-1101: ['EG10996-MONOMER']
# CPLX0-1121: ['G7845-MONOMER']
# CPLX0-1141: ['EG10941-MONOMER']
# CPLX0-1142: ['G7237-MONOMER']
# CPLX0-1161: ['EG11881-MONOMER']
# CPLX0-1162: ['EG11676-MONOMER']
# CPLX0-1163: ['CPLX0-1161', 'CPLX0-1162']
# CPLX0-1221: ['G7740-MONOMER']
# CPLX0-1241: ['EG11249-MONOMER']
# CPLX0-1242: ['CPLX0-1241', 'CPLX0-841']
# CPLX0-1261: []
# CPLX0-1262: ['G7662-MONOMER']
# CPLX0-1321: ['EG10436-MONOMER', 'EG10435-MONOMER']
# CPLX0-1341: ['G6909-MONOMER', 'G6908-MONOMER', 'G6907-MONOMER']
# CPLX0-1401: ['G7490-MONOMER']
# CPLX0-1421: ['EG10113-MONOMER']
# CPLX0-1441: ['EG10255-MONOMER']
# CPLX0-1461: ['EG10438-MONOMER']
# CPLX0-1521: ['EG11415-MONOMER']
# CPLX0-1541: ['EG11090-MONOMER']
# CPLX0-1601: ['G6845-MONOMER', 'G6846-MONOMER', 'G6847-MONOMER', 'G6848-MONOMER']
# CPLX0-1621: ['EG11299-MONOMER']
# CPLX0-1642: ['EG11879-MONOMER']
# CPLX0-1668: []
# CPLX0-1683: ['EG11692-MONOMER']
# CPLX0-1721: ['G6320-MONOMER', 'G6322-MONOMER', 'G6321-MONOMER', 'YBDE-MONOMER']
# CPLX0-1762: []
# CPLX0-1821: ['G7842-MONOMER']
# CPLX0-1841: []
# CPLX0-1863: ['G6379-MONOMER']
# CPLX0-1881: ['G7877-MONOMER']
# CPLX0-1923: []
# CPLX0-1924: []
# CPLX0-1941: []
# CPLX0-1942: []
# CPLX0-1943: []
# CPLX0-1962: ['EG12345-MONOMER']
# CPLX0-1: ['G7413-MONOMER']
# CPLX0-201: ['G6428-MONOMER']
# CPLX0-2021: []
# CPLX0-2061: ['EG12279-MONOMER']
# CPLX0-2081: ['G6627-MONOMER', 'MONOMER0-1261']
# CPLX0-2121: []
# CPLX0-2141: ['CPLX0-7964', 'EG10266-MONOMER', 'ACRF-MONOMER']
# CPLX0-2161: []
# CPLX0-2201: []
# CPLX0-221: ['APORNAP-CPLX', 'PD00440']
# CPLX0-222: ['EG11355-MONOMER', 'APORNAP-CPLX']
# CPLX0-224: ['MONOMER0-146']
# CPLX0-225: ['MONOMER-162']
# CPLX0-227: ['MONOMER0-147']
# CPLX0-229: ['RNTRACTIV-MONOMER']
# CPLX0-230: ['ICITDEHASE-KIN-PHOSPHA']
# CPLX0-231: ['GATC-MONOMER', 'GATB-MONOMER', 'GATA-MONOMER']
# CPLX0-234: ['G7423-MONOMER']
# CPLX0-235: ['MONOMER-43']
# CPLX0-2361: ['EG10238-MONOMER', 'EG10243-MONOMER', 'EG11505-MONOMER']
# CPLX0-236: ['G6770-MONOMER']
# CPLX0-237: ['SERINE-O-ACETTRAN-MONOMER']
# CPLX0-2381: []
# CPLX0-238: ['ARGSUCCINSYN-MONOMER']
# CPLX0-2401: ['TRYPSYN-BPROTEIN']
# CPLX0-240: ['TAGAALDOL1-MONOMER']
# CPLX0-2424: ['EG10687-MONOMER', 'EG10686-MONOMER']
# CPLX0-2425: ['EG10423-MONOMER', 'EG10424-MONOMER']
# CPLX0-242: ['EG10395-MONOMER']
# CPLX0-243: ['INORGPYROPHOSPHAT-MONOMER']
# CPLX0-2441: ['EG10845-MONOMER']
# CPLX0-244: ['EG11261-MONOMER']
# CPLX0-245: ['EG11384-MONOMER', 'EG11385-MONOMER']
# CPLX0-246: ['G6906-MONOMER']
# CPLX0-248: ['G7325-MONOMER']
# CPLX0-2502: ['EG11597-MONOMER', 'EG11598-MONOMER']
# CPLX0-250: []
# CPLX0-251: ['G6198-MONOMER']
# CPLX0-2521: ['MONOMER0-1501']
# CPLX0-252: ['FABH-MONOMER']
# CPLX0-253: ['EG12656-MONOMER']
# CPLX0-2541: ['MONOMER0-185']
# CPLX0-254: ['G7516-MONOMER']
# CPLX0-255: ['G7492-MONOMER']
# CPLX0-2561: []
# CPLX0-2621: ['MONOMER0-1564']
# CPLX0-263: ['MONOMER0-2', 'MONOMER0-3']
# CPLX0-2641: ['EG10461-MONOMER']
# CPLX0-2661: ['EG10574-MONOMER', 'EG10575-MONOMER']
# CPLX0-2681: ['EG10978-MONOMER']
# CPLX0-2861: ['EG10116-MONOMER']
# CPLX0-2881: ['EG10542-MONOMER']
# CPLX0-2901: ['MONOMER0-1842', 'MONOMER0-1843']
# CPLX0-2921: ['EG10463-MONOMER']
# CPLX0-2941: ['EG10968-MONOMER']
# CPLX0-2982: ['CPLX0-1321', 'EG11506-MONOMER']
# CPLX0-3001: ['EG10695-MONOMER']
# CPLX0-301: ['EG11396-MONOMER']
# CPLX0-3021: ['G7925-MONOMER']
# CPLX0-303: ['EG11517-MONOMER']
# CPLX0-3041: ['EG11549-MONOMER']
# CPLX0-3061: ['EG10694-MONOMER']
# CPLX0-3081: ['EG10697-MONOMER']
# CPLX0-3101: ['EG10158-MONOMER']
# CPLX0-3102: ['EG10159-MONOMER']
# CPLX0-3104: ['CPLX0-3101', 'CPLX0-881']
# CPLX0-3107: ['CPLX0-3101', 'CPLX0-3102']
# CPLX0-3108: ['CPLX0-3101', 'CPLX0-881', 'CPLX0-3102']
# CPLX0-3121: ['EG11723-MONOMER']
# CPLX0-3141: ['EG12657-MONOMER']
# CPLX0-3161: ['MONOMER0-1981']
# CPLX0-3181: ['MONOMER0-2001']
# CPLX0-3201: ['EG10580-MONOMER']
# CPLX0-321: ['PDXJ-MONOMER']
# CPLX0-3221: ['YRAO-MONOMER']
# CPLX0-322: ['GSK-MONOMER']
# CPLX0-3241: ['NAPG-MONOMER', 'NAPH-MONOMER']
# CPLX0-3281: ['EG10857-MONOMER']
# CPLX0-3301: ['EG11111-MONOMER']
# CPLX0-3361: ['NUOB-MONOMER', 'NUOC-MONOMER', 'NUOE-MONOMER', 'NUOF-MONOMER', 'NUOG-MONOMER', 'NUOI-MONOMER']
# CPLX0-3382: []
# CPLX0-3401: []
# CPLX0-341: ['EG10004-MONOMER']
# CPLX0-3461: ['EG10859-MONOMER']
# CPLX0-3482: ['ALDDEHYDROGB-MONOMER']
# CPLX0-3501: ['G7452-MONOMER']
# CPLX0-3521: ['EG10743-MONOMER']
# CPLX0-3541: ['EG10844-MONOMER']
# CPLX0-3561: ['EG10484-MONOMER']
# CPLX0-3581: ['EG11852-MONOMER']
# CPLX0-3601: ['G7175-MONOMER']
# CPLX0-3602: ['EG11547-MONOMER']
# CPLX0-3621: ['EG10236-MONOMER']
# CPLX0-3641: ['G6755-MONOMER']
# CPLX0-3661: ['G7590-MONOMER']
# CPLX0-3681: ['EG10838-MONOMER']
# CPLX0-3721: ['EG12633-MONOMER']
# CPLX0-3741: ['GLUTRNAREDUCT-MONOMER']
# CPLX0-3761: ['EG10242-MONOMER']
# CPLX0-3781: ['MONOMER0-1041', 'EG12844-MONOMER']
# CPLX0-3801: ['EG10245-MONOMER', 'EG11500-MONOMER', 'EG11412-MONOMER']
# CPLX0-3802: ['EG10245-MONOMER']
# CPLX0-3803: ['CPLX0-2361', 'CPLX0-3801', 'CPLX0-3761', 'CPLX0-3802', 'CPLX0-7910']
# CPLX0-3821: ['EG10483-MONOMER', 'EG10484-MONOMER']
# CPLX0-3841: ['EG11294-MONOMER']
# CPLX0-3861: ['G7724-MONOMER']
# CPLX0-3881: ['FCL-MONOMER']
# CPLX0-3901: ['EG11685-MONOMER']
# CPLX0-3921: ['G6500-MONOMER']
# CPLX0-3922: []
# CPLX0-3923: ['G6895-MONOMER']
# CPLX0-3924: ['G7865-MONOMER']
# CPLX0-3925: ['EG11056-MONOMER', 'EG11057-MONOMER']
# CPLX0-3927: ['EG11731-MONOMER']
# CPLX0-3929: ['EG10973-MONOMER']
# CPLX0-3930: ['EG10320-MONOMER', 'MONOMER0-2488']
# CPLX0-3931: ['EG10837-MONOMER']
# CPLX0-3932: ['CPLX0-7964', 'ACRD-MONOMER', 'EG11703-MONOMER']
# CPLX0-3933: ['EG10952-MONOMER', 'EG10658-MONOMER', 'G7352-MONOMER', 'G6093-MONOMER', 'G7320-MONOMER']
# CPLX0-3934: ['EG10599-MONOMER', 'EG10600-MONOMER']
# CPLX0-3936: ['H2NEOPTERINALDOL-MONOMER']
# CPLX0-3937: ['EG10252-MONOMER', 'EG10253-MONOMER']
# CPLX0-3938: ['EG12177-MONOMER']
# CPLX0-3939: ['G6334-MONOMER']
# CPLX0-3941: ['G6717-MONOMER']
# CPLX0-3943: ['G6645-MONOMER']
# CPLX0-3948: ['EG12600-MONOMER']
# CPLX0-3949: ['THIG-MONOMER', 'THIH-MONOMER']
# CPLX0-3950: ['EG11023-MONOMER']
# CPLX0-3951: ['EG10605-MONOMER']
# CPLX0-3952: ['RIBOFLAVIN-SYN-MONOMER']
# CPLX0-3954: ['EG12026-MONOMER']
# CPLX0-3955: ['EG10873-MONOMER']
# CPLX0-3956: ['EG10871-MONOMER', 'CPLX0-3955']
# CPLX0-3957: ['EG10927-MONOMER', 'EG11094-MONOMER']
# CPLX0-3958: ['EG10458-MONOMER', 'EG10459-MONOMER', 'EG10460-MONOMER']
# CPLX0-3959: []
# CPLX0-3961: ['G7058-MONOMER']
# CPLX0-3969: ['EG10921-MONOMER']
# CPLX0-3970: ['OPPB-MONOMER', 'OPPC-MONOMER', 'OPPD-MONOMER', 'OPPF-MONOMER', 'G6665-MONOMER']
# CPLX0-3971: ['EG12410-MONOMER']
# CPLX0-3: ['EG10764-MONOMER']
# CPLX0-4: []
# CPLX0-661: ['EG11241-MONOMER']
# CPLX0-682: ['MONOMER0-541']
# CPLX0-721: ['EG11816-MONOMER']
# CPLX0-7415: ['LIPIDADISACCHARIDESYNTH-MONOMER']
# CPLX0-7417: ['G6212-MONOMER']
# CPLX0-7418: ['EG10603-MONOMER']
# CPLX0-7420: ['G7327-MONOMER']
# CPLX0-7421: ['EG11888-MONOMER']
# CPLX0-7422: ['EG12309-MONOMER']
# CPLX0-7423: ['EG11254-MONOMER']
# CPLX0-7425: ['CPLX0-7757', 'EG10443-MONOMER']
# CPLX0-7426: ['OPPSYN-MONOMER']
# CPLX0-743: ['DXS-MONOMER']
# CPLX0-7444: ['EG11126-MONOMER']
# CPLX0-7451: ['EG11656-MONOMER', 'G377-MONOMER']
# CPLX0-7452: ['G361-MONOMER', 'EG10841-MONOMER']
# CPLX0-7458: []
# CPLX0-7462: ['EG11234-MONOMER']
# CPLX0-7465: ['ALARACECAT-MONOMER']
# CPLX0-7466: ['XYLULOKIN-MONOMER']
# CPLX0-7521: ['EG12319-MONOMER']
# CPLX0-7525: ['MEND-MONOMER']
# CPLX0-7529: ['G7107-MONOMER', 'G7105-MONOMER']
# CPLX0-7530: ['MONOMER0-282']
# CPLX0-7532: ['AMTB-MONOMER']
# CPLX0-7533: ['EG10670-MONOMER']
# CPLX0-7534: ['EG10671-MONOMER']
# CPLX0-7535: ['YJDE-MONOMER']
# CPLX0-7536: ['EG11663-MONOMER']
# CPLX0-7538: ['EG12878-MONOMER']
# CPLX0-7561: []
# CPLX0-7564: ['EG11081-MONOMER']
# CPLX0-7597: ['EG10375-MONOMER']
# CPLX0-7608: ['EG10997-MONOMER']
# CPLX0-7609: ['CPLX0-7608', 'CPLX0-7597']
# CPLX0-7610: []
# CPLX0-7613: ['G7286-MONOMER']
# CPLX0-7614: ['ATPPHOSRIBOSTRANS-MONOMER']
# CPLX0-7615: ['KDGALDOL-MONOMER']
# CPLX0-7616: ['G6278-MONOMER']
# CPLX0-7617: ['EG12332-MONOMER']
# CPLX0-761: []
# CPLX0-7622: ['LSERINEDEAM3-MONOMER']
# CPLX0-7623: ['G6606-MONOMER']
# CPLX0-7624: ['EG10955-MONOMER', 'G7629-MONOMER']
# CPLX0-7625: ['G7185-MONOMER']
# CPLX0-7626: ['EG11160-MONOMER']
# CPLX0-7627: ['EG11180-MONOMER']
# CPLX0-7628: ['EG11569-MONOMER', 'EG10855-MONOMER']
# CPLX0-7629: ['NHAA-MONOMER']
# CPLX0-7630: ['THIOESTERI-MONOMER']
# CPLX0-7631: ['FUCISOM-MONOMER']
# CPLX0-7632: ['PD01343']
# CPLX0-7633: ['FUCPALDOL-MONOMER']
# CPLX0-7641: ['YIIP-MONOMER']
# CPLX0-7642: ['PROP-MONOMER']
# CPLX0-7643: ['KETOLREDUCTOISOM-MONOMER']
# CPLX0-7645: ['EG10355-MONOMER']
# CPLX0-7646: ['EG10817-MONOMER']
# CPLX0-7647: ['RIBOKIN-MONOMER']
# CPLX0-7648: ['G7348-MONOMER']
# CPLX0-7649: ['EG11865-MONOMER']
# CPLX0-7652: ['RHAMNISOM-MONOMER']
# CPLX0-7653: ['AQPZ-MONOMER']
# CPLX0-7654: ['GLPF-MONOMER']
# CPLX0-7655: ['EG10528-MONOMER']
# CPLX0-7658: ['G7920-MONOMER']
# CPLX0-7659: ['RIBOFLAVINSYNDEAM-MONOMER']
# CPLX0-7660: ['G6106-MONOMER']
# CPLX0-7662: ['BETA-GLUCURONID-MONOMER']
# CPLX0-7666: ['G6088-MONOMER']
# CPLX0-7667: ['G7564-MONOMER']
# CPLX0-7668: ['EG11134-MONOMER']
# CPLX0-7669: ['EG10490-MONOMER']
# CPLX0-7672: ['CPLX0-7701']
# CPLX0-7674: ['KCH-MONOMER']
# CPLX0-7675: ['G6988-MONOMER']
# CPLX0-7678: ['CPLX0-7677']
# CPLX0-7679: ['EG11929-MONOMER']
# CPLX0-7682: ['G7748-MONOMER']
# CPLX0-7683: ['EG11845-MONOMER']
# CPLX0-7684: []
# CPLX0-7685: ['HYPOXANPRIBOSYLTRAN-MONOMER']
# CPLX0-7686: ['EG11878-MONOMER']
# CPLX0-7687: ['G6811-MONOMER']
# CPLX0-7688: ['SUCCSEMIALDDEHYDROG-MONOMER']
# CPLX0-7691: ['EG11811-MONOMER']
# CPLX0-7692: ['EG10572-MONOMER']
# CPLX0-7693: ['G6731-MONOMER']
# CPLX0-7694: ['G6261-MONOMER']
# CPLX0-7695: ['G6810-MONOMER']
# CPLX0-7696: ['EG10618-MONOMER']
# CPLX0-7697: ['EG11252-MONOMER', 'CPLX0-7698']
# CPLX0-7698: ['EG12165-MONOMER']
# CPLX0-7704: ['EG10613-MONOMER']
# CPLX0-7705: ['PD00196']
# CPLX0-7707: ['MONOMER0-1781']
# CPLX0-7708: ['CPLX0-7702']
# CPLX0-7709: ['G6644-MONOMER']
# CPLX0-7710: ['PD00364']
# CPLX0-7711: ['EG10455-MONOMER']
# CPLX0-7712: ['GDPMANMANHYDRO-MONOMER']
# CPLX0-7713: ['PD00297']
# CPLX0-7717: ['EG10748-MONOMER']
# CPLX0-7718: ['G7168-MONOMER']
# CPLX0-7719: ['QUINOLINATE-SYNTHA-MONOMER']
# CPLX0-7720: []
# CPLX0-7721: ['PHOSPHO-DCUR-MONOMER']
# CPLX0-7722: ['G7160-MONOMER']
# CPLX0-7723: ['G7158-MONOMER']
# CPLX0-7724: ['EG10284-MONOMER']
# CPLX0-7725: ['G7430-MONOMER', 'G7429-MONOMER', 'G7428-MONOMER', 'G7427-MONOMER', 'G7426-MONOMER']
# CPLX0-7726: ['G6501-MONOMER']
# CPLX0-7727: ['EG12366-MONOMER']
# CPLX0-7728: ['EG10454-MONOMER']
# CPLX0-7731: ['G6720-MONOMER']
# CPLX0-7732: ['G7263-MONOMER']
# CPLX0-7733: ['PD00250']
# CPLX0-7734: ['EG12235-MONOMER']
# CPLX0-7740: ['PD04028']
# CPLX0-7741: ['METHYLMALONYL-COA-MUT-MONOMER']
# CPLX0-7744: ['G7858-MONOMER']
# CPLX0-7745: ['G7262-MONOMER']
# CPLX0-7747: ['G6660-MONOMER']
# CPLX0-7748: ['PHOSPHO-CPXR']
# CPLX0-7754: ['PHOSPHO-UHPA']
# CPLX0-7755: ['EG12172-MONOMER']
# CPLX0-7756: ['EG11212-MONOMER']
# CPLX0-7757: ['EG10442-MONOMER']
# CPLX0-7758: ['G6550-MONOMER']
# CPLX0-7759: ['PD03938']
# CPLX0-7760: ['ACONITASE-MONOMER']
# CPLX0-7766: ['EG11105-MONOMER']
# CPLX0-7776: ['EG11245-MONOMER']
# CPLX0-7787: ['G6109-MONOMER', 'G6110-MONOMER']
# CPLX0-7788: ['G7145-MONOMER', 'EG11289-MONOMER']
# CPLX0-7789: ['EG12855-MONOMER']
# CPLX0-7791: ['EG10836-MONOMER', 'EG11131-MONOMER']
# CPLX0-7794: ['EG11847-MONOMER']
# CPLX0-7795: ['PHOSPHO-KDPE']
# CPLX0-7796: ['MONOMER0-157']
# CPLX0-7797: ['PD00197']
# CPLX0-7801: ['G7271-MONOMER']
# CPLX0-7802: ['EG11643-MONOMER']
# CPLX0-7805: ['G6157-MONOMER', 'G6156-MONOMER', 'G6155-MONOMER']
# CPLX0-7806: ['G7194-MONOMER']
# CPLX0-7807: []
# CPLX0-7808: ['COPROGENOXI-MONOMER']
# CPLX0-7810: ['EG11735-MONOMER']
# CPLX0-7811: ['PROTOPORGENOXI-MONOMER']
# CPLX0-7816: ['EG11100-MONOMER']
# CPLX0-7817: ['EG12181-MONOMER']
# CPLX0-7819: ['KEFC-MONOMER']
# CPLX0-7820: ['G6804-MONOMER']
# CPLX0-7822: ['G7571-MONOMER', 'G7572-MONOMER']
# CPLX0-7823: []
# CPLX0-7824: ['EG11378-MONOMER']
# CPLX0-7826: ['G7530-MONOMER']
# CPLX0-7827: ['G6326-MONOMER']
# CPLX0-782: ['EG11306-MONOMER']
# CPLX0-7835: ['G7287-MONOMER']
# CPLX0-7836: ['G7292-MONOMER']
# CPLX0-7837: ['EG11132-MONOMER']
# CPLX0-7838: ['G7454-MONOMER']
# CPLX0-7839: ['G7455-MONOMER']
# CPLX0-7841: ['ALPHACOMP-MONOMER']
# CPLX0-7843: ['FOCA-MONOMER']
# CPLX0-7844: ['G6669-MONOMER', 'G6670-MONOMER']
# CPLX0-7847: ['PDXA-MONOMER']
# CPLX0-7848: ['G7855-MONOMER']
# CPLX0-7852: ['RCSB-MONOMER', 'EG11544-MONOMER']
# CPLX0-7853: ['EG11835-MONOMER']
# CPLX0-7854: ['EG12202-MONOMER']
# CPLX0-7870: ['ATOS-MONOMER']
# CPLX0-7877: ['PGLUCISOM']
# CPLX0-7878: ['G7236-MONOMER']
# CPLX0-7879: ['EG10909-MONOMER', 'EG10666-MONOMER']
# CPLX0-7882: ['NAPHTHOATE-SYN-MONOMER']
# CPLX0-7885: []
# CPLX0-7887: ['G7242-MONOMER']
# CPLX0-7888: ['G7184-MONOMER']
# CPLX0-7889: ['EG11211-MONOMER']
# CPLX0-7904: ['EG12030-MONOMER']
# CPLX0-7906: ['CAIT-MONOMER']
# CPLX0-7908: ['EG12132-MONOMER']
# CPLX0-7909: []
# CPLX0-7910: ['EG11413-MONOMER', 'EG11414-MONOMER']
# CPLX0-7912: ['G7288-MONOMER']
# CPLX0-7913: ['EG11884-MONOMER']
# CPLX0-7914: ['G7425-MONOMER']
# CPLX0-7916: ['G7948-MONOMER', 'RCSB-MONOMER']
# CPLX0-7917: ['G7553-MONOMER']
# CPLX0-7921: ['MANX-MONOMER']
# CPLX0-7922: ['EG11191-MONOMER']
# CPLX0-7923: ['G6939-MONOMER']
# CPLX0-7927: ['G6760-MONOMER']
# CPLX0-7928: ['EG10836-MONOMER']
# CPLX0-7929: ['EG12844-MONOMER']
# CPLX0-7932: ['CYTDEAM-MONOMER']
# CPLX0-7933: ['G7489-MONOMER']
# CPLX0-7934: []
# CPLX0-7935: ['EG10719-MONOMER', 'EG10718-MONOMER', 'EG10717-MONOMER', 'EG10716-MONOMER']
# CPLX0-7936: ['EG10725-MONOMER']
# CPLX0-7938: ['PTSI-MONOMER']
# CPLX0-7939: ['EG11568-MONOMER']
# CPLX0-7940: ['G6140-MONOMER']
# CPLX0-7942: ['EG10125-MONOMER', 'EG12181-MONOMER']
# CPLX0-7944: ['MONOMER0-341']
# CPLX0-7945: ['G6540-MONOMER']
# CPLX0-7946: ['EG10852-MONOMER']
# CPLX0-7947: ['SUCCARGDIHYDRO-MONOMER']
# CPLX0-7950: ['MHPCHYDROL-MONOMER']
# CPLX0-7951: ['MHPDHYDROL-MONOMER']
# CPLX0-7952: ['EG10306-MONOMER']
# CPLX0-7955: ['YJCG-MONOMER']
# CPLX0-7956: ['EG11447-MONOMER']
# CPLX0-7957: ['EG10943-MONOMER']
# CPLX0-7958: []
# CPLX0-7959: ['ASL-MONOMER']
# CPLX0-7960: ['HMP-KIN-MONOMER']
# CPLX0-7961: ['YADQ-MONOMER']
# CPLX0-7962: ['G6759-MONOMER']
# CPLX0-7963: ['EMRE-MONOMER']
# CPLX0-7964: ['EG11009-MONOMER']
# CPLX0-7970: ['G7924-MONOMER']
# CPLX0-7973: ['EG12313-MONOMER']
# CPLX0-7974: ['EG11702-MONOMER']
# CPLX0-7975: ['PD04413']
# CPLX0-7976: ['G7874-MONOMER']
# CPLX0-7977: ['EG11085-MONOMER']
# CPLX0-7979: ['EG10144-MONOMER']
# CPLX0-7981: ['G6323-MONOMER']
# CPLX0-7982: ['MONOMER0-82']
# CPLX0-7983: ['G6417-MONOMER']
# CPLX0-7984: ['G7616-MONOMER']
# CPLX0-7985: ['G7840-MONOMER']
# CPLX0-7986: ['EG10486-MONOMER', 'EG10485-MONOMER']
# CPLX0-7987: ['G7626-MONOMER']
# CPLX0-7988: ['G6715-MONOMER', 'G6714-MONOMER']
# CPLX0-7989: ['G6662-MONOMER']
# CPLX0-7990: ['RFFTRANS-MONOMER']
# CPLX0-7992: ['CPLX0-7628', 'G7889-MONOMER', 'G7664-MONOMER', 'YHBN-MONOMER', 'YHBG-MONOMER', 'G7888-MONOMER']
# CPLX0-7993: ['G6286-MONOMER']
# CPLX0-7994: ['G6528-MONOMER', 'G6529-MONOMER']
# CPLX0-7997: ['DIAMINOPIMEPIM-MONOMER']
# CPLX0-7998: ['EG12146-MONOMER']
# CPLX0-7: ['MONOMER0-5', 'CRR-MONOMER']
# CPLX0-8005: ['3-OXOACYL-ACP-REDUCT-MONOMER']
# CPLX0-8006: ['ENOYL-ACP-REDUCT-NADH-MONOMER']
# CPLX0-8008: ['UDPGLCNACEPIM-MONOMER']
# CPLX0-8010: ['G7020-MONOMER']
# CPLX0-8011: ['GLCNACPTRANS-MONOMER']
# CPLX0-8012: ['DTDPGLUCOSEPP2-MONOMER']
# CPLX0-8013: ['UDPMANNACADEHYDROG-MONOMER']
# CPLX0-8014: ['UDP-NACMUR-ALA-LIG-MONOMER']
# CPLX0-8015: ['ADHP-MONOMER']
# CPLX0-8016: ['UDPHYDROXYMYRGLUCOSAMNACETYLTRANS-MONO']
# CPLX0-801: ['EG11398-MONOMER']
# CPLX0-8031: ['PDXY-MONOMER']
# CPLX0-8032: ['G7234-MONOMER']
# CPLX0-8033: ['EG11101-MONOMER']
# CPLX0-8034: ['DTDPGLUCOSEPP-MONOMER']
# CPLX0-8043: ['G6799-MONOMER']
# CPLX0-8044: ['EG11828-MONOMER']
# CPLX0-8045: ['EG10153-MONOMER']
# CPLX0-8046: ['SECB']
# CPLX0-8089: ['SECA']
# CPLX0-8090: ['G6673-MONOMER']
# CPLX0-8092: ['EG10564-MONOMER']
# CPLX0-8095: ['G7365-MONOMER']
# CPLX0-8096: ['G7885-MONOMER']
# CPLX0-8097: ['SBMA-MONOMER']
# CPLX0-8098: ['UGD-MONOMER']
# CPLX0-8102: ['TAR-MONOMER']
# CPLX0-8103: ['TSR-MONOMER']
# CPLX0-8104: ['TAP-MONOMER']
# CPLX0-8105: ['TRG-MONOMER']
# CPLX0-8106: ['EG11298-MONOMER']
# CPLX0-8107: ['EG11535-MONOMER']
# CPLX0-8108: ['EG11534-MONOMER']
# CPLX0-8109: ['EG11236-MONOMER']
# CPLX0-8110: ['G6154-MONOMER']
# CPLX0-8111: ['EG11064-MONOMER']
# CPLX0-8112: ['EG11430-MONOMER']
# CPLX0-8113: ['EG10735-MONOMER']
# CPLX0-8119: ['MONOMER0-6', 'G7250-MONOMER', 'G7246-MONOMER']
# CPLX0-8120: ['ARTI-MONOMER', 'ARTM-MONOMER', 'ARTQ-MONOMER', 'ARTP-MONOMER']
# CPLX0-8121: ['EG11315-MONOMER']
# CPLX0-8122: ['EG12310-MONOMER']
# CPLX0-8123: ['G7431-MONOMER']
# CPLX0-8124: ['G6675-MONOMER']
# CPLX0-8125: []
# CPLX0-8127: ['G6721-MONOMER']
# CPLX0-8128: ['G6912-MONOMER']
# CPLX0-8129: ['G6303-MONOMER']
# CPLX0-8152: ['EG12347-MONOMER', 'G7037-MONOMER', 'G7039-MONOMER']
# CPLX0-8154: ['G7880-MONOMER']
# CPLX0-8155: ['G7816-MONOMER']
# CPLX0-8156: ['EG10698-MONOMER']
# CPLX0-8157: ['EG10680-MONOMER']
# CPLX0-8158: ['DLACTDEHYDROGNAD-MONOMER']
# CPLX0-8159: ['G7596-MONOMER']
# CPLX0-8160: ['SUCC-DEHASE']
# CPLX0-8163: ['EG11511-MONOMER']
# CPLX0-8164: ['EG10154-MONOMER']
# CPLX0-8165: ['EG10976-MONOMER']
# CPLX0-8167: ['FORMHYDROGI-CPLX']
# CPLX0-8168: ['PHOQ-MONOMER']
# CPLX0-8173: ['EG12845-MONOMER']
# CPLX0-8174: ['CPLX0-8173', 'CPLX0-7914']
# CPLX0-8175: ['EG11859-MONOMER']
# CPLX0-8176: ['G7456-MONOMER']
# CPLX0-8177: ['MONOMER0-1701']
# CPLX0-8180: ['EG10157-MONOMER']
# CPLX0-8181: ['G6991-MONOMER', 'EG11171-MONOMER']
# CPLX0-8182: ['EG11757-MONOMER']
# CPLX0-8183: ['EG11652-MONOMER']
# CPLX0-8184: ['EG11580-MONOMER']
# CPLX0-8185: ['EG12391-MONOMER']
# CPLX0-8186: ['GALACTITOLPDEHYD-MONOMER']
# CPLX0-8187: ['G7682-MONOMER']
# CPLX0-8188: ['EG10597-MONOMER', 'EG10596-MONOMER']
# CPLX0-8189: ['G7350-MONOMER']
# CPLX0-8190: ['G7021-MONOMER']
# CPLX0-8191: ['EG10240-MONOMER']
# CPLX0-8192: ['EG10416-MONOMER']
# CPLX0-8196: ['EG10596-MONOMER']
# CPLX0-8198: ['EG12371-MONOMER']
# CPLX0-8199: ['G6783-MONOMER']
# CPLX0-8200: ['G7314-MONOMER']
# CPLX0-8201: ['G7394-MONOMER']
# CPLX0-8202: ['ALARACEBIOSYN-MONOMER']
# CPLX0-8204: ['EG11918-MONOMER']
# CPLX0-8205: ['GLUC1PURIDYLTRANS-MONOMER']
# CPLX0-8206: ['EG12399-MONOMER']
# CPLX0-8207: ['EG11399-MONOMER']
# CPLX0-8208: []
# CPLX0-8211: ['THZ-KIN-MONOMER']
# CPLX0-8212: ['ERYTHRON4PDEHYDROG-MONOMER']
# CPLX0-8213: ['G7060-MONOMER', 'G7059-MONOMER']
# CPLX0-8214: ['G7853-MONOMER']
# CPLX0-8217: ['G7005-MONOMER']
# CPLX0-8218: ['G6784-MONOMER']
# CPLX0-8219: ['G7398-MONOMER']
# CPLX0-821: ['G7723-MONOMER']
# CPLX0-8223: ['EG12179-MONOMER']
# CPLX0-8227: ['EG10307-MONOMER', 'EG12374-MONOMER']
# CPLX0-8229: ['G7601-MONOMER']
# CPLX0-8230: ['CPLX0-8229', 'G7602-MONOMER']
# CPLX0-8231: ['G7641-MONOMER']
# CPLX0-8232: []
# CPLX0-8233: ['EG12033-MONOMER']
# CPLX0-8234: ['G6209-MONOMER']
# CPLX0-8237: ['G6306-MONOMER']
# CPLX0-8238: ['NRFD-MONOMER', 'NRFC-MONOMER']
# CPLX0-8239: ['G7657-MONOMER', 'EG12181-MONOMER']
# CPLX0-8240: ['EG11404-MONOMER']
# CPLX0-8244: ['G6491-MONOMER']
# CPLX0-8245: ['EG10018-MONOMER']
# CPLX0-8247: ['URAA-MONOMER']
# CPLX0-8248: ['G7192-MONOMER']
# CPLX0-8249: []
# CPLX0-8251: ['EG11157-MONOMER']
# CPLX0-8252: ['EG10201-MONOMER']
# CPLX0-8254: ['EG10203-MONOMER']
# CPLX0-8255: []
# CPLX0-8256: ['EG10466-MONOMER']
# CPLX0-8259: ['EG11870-MONOMER']
# CPLX0-8260: ['DTMPKI-MONOMER']
# CPLX0-8261: []
# CPLX0-8262: ['EG12373-MONOMER']
# CPLX0-8263: ['SUGE-MONOMER']
# CPLX0-8269: ['G7597-MONOMER']
# CPLX0-8270: ['CPXA-MONOMER']
# CPLX0-8271: ['EG12209-MONOMER']
# CPLX0-8275: ['G7345-MONOMER']
# CPLX0-8280: ['G6358-MONOMER']
# CPLX0-8281: ['G6865-MONOMER']
# CPLX0-8285: ['OMPR-MONOMER']
# CPLX0-8288: ['G6318-MONOMER']
# CPLX0-8290: ['G7248-MONOMER']
# CPLX0-8291: ['G7531-MONOMER']
# CPLX0-8292: ['GLUCONREDUCT-MONOMER']
# CPLX0-8299: ['PRPPSYN-MONOMER']
# CPLX0-8300: ['MONOMER0-4521']
# CPLX0-8301: []
# CPLX0-8302: ['BARA-MONOMER']
# CPLX0-8303: ['G6520-MONOMER']
# CPLX0-8304: ['DCUB-MONOMER', 'DCUS-MONOMER']
# CPLX0-8306: ['DCTA-MONOMER', 'DCUS-MONOMER']
# CPLX0-8308: ['G7653-MONOMER', 'G7652-MONOMER']
# CPLX0-8311: ['MONOMER0-1041']
# CPLX0-8312: []
# CPLX0-8314: ['EVGS-MONOMER']
# CPLX0-8315: ['EG10574-MONOMER']
# CPLX0-841: ['EG10571-MONOMER']
# CPLX0-8535: ['EG12396-MONOMER']
# CPLX0-8536: []
# CPLX0-8537: ['GALACTARDEHYDRA-MONOMER']
# CPLX0-8538: ['G6708-MONOMER']
# CPLX0-8539: ['G7689-MONOMER', 'EG10741-MONOMER']
# CPLX0-8541: []
# CPLX0-8542: ['G6174-MONOMER']
# CPLX0-8544: ['G7901-MONOMER']
# CPLX0-8545: ['EG10202-MONOMER']
# CPLX0-8547: ['G6960-MONOMER']
# CPLX0-8548: ['G6959-MONOMER']
# CPLX0-8549: ['EG11436-MONOMER']
# CPLX0-8550: ['G6577-MONOMER']
# CPLX0-8551: ['G7007-MONOMER']
# CPLX0-8553: ['EG10155-MONOMER']
# CPLX0-8554: ['G6652-MONOMER']
# CPLX0-8555: ['EG12256-MONOMER']
# CPLX0-8556: ['EG11257-MONOMER']
# CPLX0-8557: ['EG10215-MONOMER']
# CPLX0-8558: ['THIF-MONOMER']
# CPLX0-8560: ['EG12690-MONOMER']
# CPLX0-8561: ['G6329-MONOMER']
# CPLX0-8562: ['G7696-MONOMER']
# CPLX0-8563: ['G6882-MONOMER']
# CPLX0-8565: ['EG11825-MONOMER']
# CPLX0-8571: ['G6862-MONOMER']
# CPLX0-8573: ['G7193-MONOMER']
# CPLX0-8574: ['G7188-MONOMER']
# CPLX0-8576: ['G7727-MONOMER']
# CPLX0-8578: ['G7790-MONOMER']
# CPLX0-8581: ['EG11548-MONOMER']
# CPLX0-8582: ['GALPMUT-MONOMER']
# CPLX0-8583: ['PHOSGLUCOSAMINEMUT-MONOMER']
# CPLX0-8584: ['EG11905-MONOMER']
# CPLX0-8585: ['EG11390-MONOMER']
# CPLX0-8586: ['G7031-MONOMER']
# CPLX0-8587: ['EG11877-MONOMER']
# CPLX0-8588: ['NANK-MONOMER']
# CPLX0-8589: ['G6521-MONOMER']
# CPLX0-8593: ['G7678-MONOMER']
# CPLX0-8595: ['EG10143-MONOMER']
# CPLX0-8596: ['EG10828-MONOMER']
# CPLX0-8597: ['G6444-MONOMER']
# CPLX0-8612: ['EG10609-MONOMER']
# CPLX0-8613: ['G6851-MONOMER']
# CPLX0-8614: ['TDPFUCACTRANS-MONOMER']
# CPLX0-8615: ['MALTODEXGLUCOSID-MONOMER']
# CPLX0-8616: ['G6621-MONOMER']
# CPLX0-8617: ['EG11167-MONOMER']
# CPLX0-8618: []
# CPLX0-8619: ['EG12159-MONOMER']
# CPLX0-861: ['G7055-MONOMER']
# CPLX0-8762: ['FORMHYDROG2-CPLX']
# CPLX0-8791: ['G7399-MONOMER']
# CPLX0-881: ['EG10156-MONOMER']
# CPLX0-901: ['EG11372-MONOMER']
# CPLX0-902: ['EG11761-MONOMER']
# CPLX0-921: ['G6104-MONOMER']
# CPLX0-9372: []
# CPLX0-9749: ['G6913-MONOMER']
# CPLX0-981: ['EG12344-MONOMER']
# CPLX0-9871: []
# CPLXECOLI-7943: ['G7409-MONOMER']
# CREC-CPLX: ['CREC-MONOMER']
# CTPSYN-CPLX: ['CTPSYN-MONOMER']
# CYANLY-CPLX: ['CYANLY-MONOMER']
# CYSSYNMULTI-CPLX: ['CPLX0-237', 'ACSERLYA-CPLX']
# CYSTATHIONINE-BETA-LYASE-CPLX: ['CYSTATHIONINE-BETA-LYASE-MONOMER']
# CYT-D-UBIOX-CPLX: ['CYDA-MONOMER', 'CYDB-MONOMER', 'MONOMER0-2663', 'MONOMER0-2822']
# CYT-O-UBIOX-CPLX: ['CYOD-MONOMER', 'CYOA-MONOMER', 'CYOB-MONOMER', 'CYOC-MONOMER']
# CYTIDEAM-CPLX: ['CYTIDEAM-MONOMER']
# DALADALALIGB-CPLX: ['DALADALALIGB-MONOMER']
# DALADEHYDROG-CPLX: ['DALADEHYDROGA-MONOMER']
# DAPASYN-CPLX: ['DAPASYN-MONOMER']
# DCTP-DEAM-CPLX: ['DCTP-DEAM-MONOMER']
# DCYSDESULF-CPLX: ['DCYSDESULF-MONOMER']
# DEOA-CPLX: ['DEOA-MONOMER']
# DEOD-CPLX: ['DEOD-MONOMER']
# DETHIOBIOTIN-SYN-CPLX: ['DETHIOBIOTIN-SYN-MONOMER']
# DGTPTRIPHYDRO-CPLX: ['DGTPTRIPHYDRO-MONOMER']
# DHPDIOXYGEN-CPLX: ['DHPDIOXYGEN-MONOMER']
# DIACYLGLYKIN-CPLX: ['DIACYLGLYKIN-MONOMER']
# DIAMINOPIMDECARB-CPLX: ['DIAMINOPIMDECARB-MONOMER']
# DIHYDRODIPICSYN-CPLX: ['DIHYDRODIPICSYN-MONOMER']
# DIHYDROOROT-CPLX: ['DIHYDROOROT-MONOMER']
# DIHYDROPICRED-CPLX: ['DIHYDROPICRED-MONOMER']
# DIHYDROPTERIREDUCT-CPLX: ['DIHYDROPTERIREDUCT-MONOMER']
# DIHYDROXYACIDDEHYDRAT-CPLX: ['DIHYDROXYACIDDEHYDRAT-MONOMER']
# DIMESULFREDUCT-CPLX: ['DMSA-MONOMER', 'DMSB-MONOMER', 'DMSC-MONOMER']
# DIOHBUTANONEPSYN-CPLX: ['DIOHBUTANONEPSYN-MONOMER']
# DMBPPRIBOSYLTRANS-CPLX: ['DMBPPRIBOSYLTRANS-MONOMER']
# DSBC-CPLX: ['DSBC-MONOMER']
# DSBG-CPLX: ['DSBG-MONOMER']
# DTDPGLUCDEHYDRAT-CPLX: ['DTDPGLUCDEHYDRAT-MONOMER']
# DUTP-PYROP-CPLX: ['DUTP-PYROP-MONOMER']
# DXPREDISOM-CPLX: ['DXPREDISOM-MONOMER']
# E1O: ['E1O-MONOMER']
# E1P-CPLX: ['E1P-MONOMER']
# E2O: ['E2O-MONOMER']
# E3-CPLX: ['E3-MONOMER']
# EIISGA: ['YJFU-MONOMER', 'YJFT-MONOMER', 'SGAT-MONOMER']
# EIISGC: []
# ENOLASE-CPLX: ['ENOLASE-MONOMER']
# ENTA-CPLX: ['ENTA-MONOMER']
# ENTE-CPLX: ['ENTE-MONOMER']
# ENTMULTI-CPLX: ['ENTB-CPLX', 'ENTD-MONOMER', 'ENTF-PANT', 'ENTE-CPLX']
# ENVZ-CPLX: ['ENVZ-MONOMER']
# ERYTH4PDEHYDROG-CPLX: ['ERYTH4PDEHYDROG-MONOMER']
# ETHAMLY-CPLX: ['EUTB-MONOMER', 'EUTC-MONOMER']
# F-1-CPLX: ['ATPC-MONOMER', 'ATPH-MONOMER', 'ATPA-CPLX', 'ATPG-MONOMER', 'ATPD-CPLX']
# F-O-CPLX: ['ATPE-CPLX', 'ATPF-CPLX', 'ATPB-MONOMER']
# F16B-CPLX: ['F16B-MONOMER']
# FABA-CPLX: ['FABA-MONOMER']
# FABB-CPLX: ['FABB-MONOMER']
# FABZ-CPLX: ['FABZ-MONOMER']
# FAO-CPLX: ['FADB-MONOMER', 'FADA-MONOMER']
# FHLMULTI-CPLX: ['FORMATEDEHYDROGH-MONOMER', 'HYDROG3-CPLX']
# FLAGELLAR-MOTOR-COMPLEX: []
# FOLD-CPLX: ['FOLD-MONOMER']
# FOLE-CPLX: ['GTP-CYCLOHYDRO-I-MONOMER']
# FOLXTET-CPLX: ['H2NTPEPIM-MONOMER']
# FORMATEDEHYDROGN-CPLX: ['ALPHA-SUBUNIT-CPLX']
# FORMATEDEHYDROGO-CPLX: ['FDOG-MONOMER', 'FDOH-MONOMER', 'FDOI-MONOMER']
# FORMHYDROG2-CPLX: ['HYBA-MONOMER', 'EG11800-MONOMER', 'MONOMER0-145', 'HYBC-MONOMER']
# FORMHYDROGI-CPLX: ['HYAA-MONOMER', 'HYAB-MONOMER', 'HYAC-MONOMER']
# FORMYLTHFDEFORMYL-CPLX: ['FORMYLTHFDEFORMYL-MONOMER']
# FRUCBISALD-CLASSII: ['FRUCTBISALD-CLASSII-MONOMER']
# FRUCBISALD-CLASSI: ['FRUCBISALD-CLASSI-MONOMER']
# FUMARASE-A: ['FUMA-MONOMER']
# FUMARASE-B: ['FUMB-MONOMER']
# FUMARASE-C: ['FUMC-MONOMER']
# FUMARATE-REDUCTASE: ['FUM-FLAVO', 'FUM-FE-S', 'FUM-MEMB1', 'FUM-MEMB2']
# GABATRANSAM-CPLX: ['GABATRANSAM-MONOMER']
# GALACTOACETYLTRAN-CPLX: ['GALACTOACETYLTRAN-MONOMER']
# GALACTURIDYLYLTRANS-CPLX: ['GALACTURIDYLYLTRANS-MONOMER']
# GAPDH-A-CPLX: ['GAPDH-A-MONOMER']
# GCVMULTI-CPLX: ['E3-CPLX', 'GCVP-CPLX', 'LIPOYL-GCVH', 'GCVT-MONOMER']
# GCVP-CPLX: ['GCVP-MONOMER']
# GDHA-CPLX: ['GDHA-MONOMER']
# GDPMANDEHYDRA-CPLX: ['GDPMANDEHYDRA-MONOMER']
# GLNG-CPLX: ['PROTEIN-NRI']
# GLNL-CPLX: ['PROTEIN-NRII']
# GLUC1PADENYLTRANS-CPLX: ['GLUC1PADENYLTRANS-MONOMER']
# GLUCONOKINII-CPLX: ['GLUCONOKINII-MONOMER']
# GLUCOSAMINE-6-P-DEAMIN-CPLX: ['GLUCOSAMINE-6-P-DEAMIN-MONOMER']
# GLUCOSE-1-PHOSPHAT-CPLX: ['GLUCOSE-1-PHOSPHAT-MONOMER']
# GLUTAMATESYN-CPLX: ['GLUTAMATESYN-DIMER']
# GLUTAMATESYN-DIMER: ['GLUSYNSMALL-MONOMER', 'GLUSYNLARGE-MONOMER']
# GLUTAMIDOTRANS-CPLX: ['GLUTAMIDOTRANS-MONOMER', 'CYCLASE-MONOMER']
# GLUTAMINESYN-OLIGOMER: ['GLUTAMINESYN-MONOMER']
# GLUTATHIONE-REDUCT-NADPH-CPLX: ['GLUTATHIONE-REDUCT-NADPH-MONOMER']
# GLUTATHIONE-SYN-CPLX: ['GLUTATHIONE-SYN-MONOMER']
# GLUTDECARBOXA-CPLX: ['GLUTDECARBOXA-MONOMER']
# GLUTDECARBOXB-CPLX: ['GLUTDECARBOXB-MONOMER']
# GLUTKIN-CPLX: ['GLUTKIN-MONOMER']
# GLUTSEMIALDEHYDROG-CPLX: ['GLUTSEMIALDEHYDROG-MONOMER']
# GLYC3PDEHYDROGBIOSYN-CPLX: ['GLYC3PDEHYDROGBIOSYN-MONOMER']
# GLYCDEH-CPLX: ['GLYCDEH-MONOMER']
# GLYCEROL-KIN-CPLX: ['GLYCEROL-KIN-MONOMER']
# GLYCOPHOSPHORYL-CPLX: ['GLYCOPHOSPHORYL-MONOMER']
# GLYCPDIESTER-PERI-CPLX: ['GLYCPDIESTER-PERI-MONOMER']
# GLYOCARBOLIG-CPLX: ['GLYOCARBOLIG-MONOMER']
# GLYOHMETRANS-CPLX: ['GLYOHMETRANS-MONOMER']
# GLYOXI-CPLX: ['GLYOXI-MONOMER']
# GLYS-CPLX: ['GLYS-MONOMER', 'GLYQ-MONOMER']
# GMP-REDUCT-CPLX: ['GMP-REDUCT-MONOMER']
# GMP-SYN-CPLX: ['GMP-SYN-MONOMER']
# GPT-CPLX: ['GPT-MONOMER']
# GSAAMINOTRANS-CPLX: ['GSAAMINOTRANS-MONOMER']
# GSP-CPLX: ['GSP-MONOMER']
# GST-CPLX: ['GST-MONOMER']
# GTP-CYCLOHYDRO-II-CPLX: ['GTP-CYCLOHYDRO-II-MONOMER']
# GUANYL-KIN-CPLX: ['GUANYL-KIN-MONOMER']
# H2PTEROATESYNTH-CPLX: ['H2PTEROATESYNTH-MONOMER']
# HCAMULTI-CPLX: []
# HISS-CPLX: ['HISS-MONOMER']
# HISTDEHYD-CPLX: ['HISTDEHYD-MONOMER']
# HISTPHOSTRANS-CPLX: ['HISTPHOSTRANS-MONOMER']
# HMP-P-KIN-CPLX: ['HMP-P-KIN-MONOMER']
# HOLO-ACP-SYNTH-CPLX: ['HOLO-ACP-SYNTH-MONOMER']
# HOMOSERKIN-CPLX: ['HOMOSERKIN-MONOMER']
# HOMSUCTRAN-CPLX: ['HOMSUCTRAN-MONOMER']
# HYDROG3-CPLX: []
# HYDROPEROXIDI-CPLX: ['HYDROPEROXIDI-MONOMER']
# HYDROPEROXIDII-CPLX: ['HYDROPEROXIDII-MONOMER']
# IMIDHISTID-CPLX: ['IMIDPHOSPHADEHYDHISTIDPHOSPHA-MONOMER']
# IMP-DEHYDROG-CPLX: ['IMP-DEHYDROG-MONOMER']
# ISOCIT-LYASE: ['ISOCIT-LYASE-MONOMER']
# ISOCITHASE-CPLX: ['ISOCITDEH-SUBUNIT']
# KDO-8PPHOSPHAT-CPLX: ['G7663-MONOMER']
# KDO-8PSYNTH-CPLX: ['KDO-8PSYNTH-MONOMER']
# KDPD-CPLX: ['KDPD-MONOMER']
# KDPGALDOL-4OH2OXOGLUTARALDOL-CPLX: ['KDPGALDOL-4OH2OXOGLUTARALDOL-MONOMER']
# L-GLN-FRUCT-6-P-AMINOTRANS-CPLX: ['L-GLN-FRUCT-6-P-AMINOTRANS-MONOMER']
# LACTALDREDUCT-CPLX: ['LACTALDREDUCT-MONOMER']
# LDC2-CPLX: ['LDC2-MONOMER']
# LTAA-CPLX: ['LTAA-MONOMER']
# LTARTDEHYDRA-CPLX: ['TTDA-MONOMER', 'TTDB-MONOMER']
# LUMAZINESYN-CPLX: ['LUMAZINESYN-MONOMER']
# LYSDECARBOX-CPLX: ['LYSDECARBOX-MONOMER']
# LYSS-CPLX: ['LYSS-MONOMER']
# LYSU-CPLX: ['LYSU-MONOMER']
# LYXK-CPLX: ['LYXK-MONOMER']
# MALATE-DEHASE: ['MALATE-DEHASE-MONOMER']
# MALDEXPHOSPHORYL-CPLX: ['MALDEXPHOSPHORYL-MONOMER']
# MALIC-NAD-CPLX: ['MALIC-NAD-MONOMER']
# MALIC-NADP-CPLX: ['MALIC-NADP-MONOMER']
# MALTACETYLTRAN-CPLX: ['MALTACETYLTRAN-MONOMER']
# MENE-CPLX: ['O-SUCCINYLBENZOATE-COA-LIG-MONOMER']
# MENF-CPLX: ['MENF-MONOMER']
# METG-CPLX: ['METG-MONOMER']
# METHGLYSYN-CPLX: ['METHGLYSYN-MONOMER']
# METHYLENETHFREDUCT-CPLX: ['METHYLENETHFREDUCT-MONOMER']
# METNIQ-METHIONINE-ABC-CPLX: ['ABC-MONOMER', 'METI-MONOMER', 'METQ-MONOMER']
# MUTHLS-CPLX: ['EG10625-MONOMER']
# N-ACETYLTRANSFER-CPLX: ['N-ACETYLTRANSFER-MONOMER']
# NAD-SYNTH-CPLX: ['NAD-SYNTH-MONOMER']
# NADH-DHI-CPLX: ['NUOA-MONOMER', 'NUOH-MONOMER', 'NUOJ-MONOMER', 'NUOK-MONOMER', 'NUOL-MONOMER', 'NUOM-MONOMER', 'NUON-MONOMER', 'CPLX0-3361']
# NAG1P-URIDYLTRANS-CPLX: ['NAG1P-URIDYLTRANS-MONOMER']
# NAG6PDEACET-CPLX: ['NAG6PDEACET-MONOMER']
# NAP-CPLX: ['NAPB-MONOMER', 'NAPA-MONOMER']
# NARQ-CPLX: ['NARQ-MONOMER']
# NARX-CPLX: ['NARX-MONOMER']
# NITRATREDUCTA-CPLX: ['NARG-MONOMER', 'NARH-MONOMER', 'NARI-MONOMER']
# NITRATREDUCTZ-CPLX: ['NARY-MONOMER', 'NARZ-MONOMER', 'NARV-MONOMER']
# NITRITREDUCT-CPLX: []
# NQOR-CPLX: ['NQOR-MONOMER']
# NRDACTMULTI-CPLX: []
# NRDE-CPLX: ['NRDE-MONOMER']
# NRDF-CPLX: ['NRDF-MONOMER']
# NRFMULTI-CPLX: ['CYTOCHROMEC552-MONOMER', 'CYTOCHROMEC-MONOMER']
# NUCLEOSIDE-DIP-KIN-CPLX: ['NUCLEOSIDE-DIP-KIN-MONOMER']
# O-SUCCHOMOSERLYASE-CPLX: ['O-SUCCHOMOSERLYASE-MONOMER']
# ORNCARBAMTRANSFERF-CPLX: ['CHAINF-MONOMER']
# ORNCARBAMTRANSFERI-CPLX: ['CHAINI-MONOMER']
# ORNDECARBOX-BIO-CPLX: ['ORNDECARBOX-BIO-MONOMER']
# ORNDECARBOXDEG-CPLX: ['ORNDECARBOXDEG-MONOMER']
# OROPRIBTRANS-CPLX: ['OROPRIBTRANS-MONOMER']
# OROTPDECARB-CPLX: ['OROTPDECARB-MONOMER']
# PABASYN-CPLX: ['PABASYN-COMPI-MONOMER', 'PABASYN-COMPII-MONOMER']
# PANTOATE-BETA-ALANINE-LIG-CPLX: ['PANTOATE-BETA-ALANINE-LIG-MONOMER']
# PANTOTHENATE-KIN-CPLX: ['PANTOTHENATE-KIN-MONOMER']
# PAPSSULFOTRANS-CPLX: ['PAPSSULFOTRANS-MONOMER']
# PC00003: ['PD00242']
# PC00004: ['PD00257']
# PC00005: ['PD00194']
# PC00007: ['PD00423']
# PC00010: ['PD00205']
# PC00027: []
# PC00033: ['PD00219']
# PC00040: ['PD00232']
# PC00061: ['PD00521']
# PC00084: ['RCSB-MONOMER', 'PD02233']
# PC00086: ['PD00221']
# PC00103: ['PD01103']
# PDXH-CPLX: ['PDXH-MONOMER']
# PDXK-CPLX: ['PDXK-MONOMER']
# PEPCARBOX-CPLX: ['PEPCARBOX-MONOMER']
# PEPSYNTH-CPLX: ['PEPSYNTH-MONOMER']
# PGLYCDEHYDROG-CPLX: ['PGLYCDEHYDROG-MONOMER']
# PHENDEHYD-CPLX: ['PHENDEHYD-MONOMER']
# PHES-CPLX: ['PHES-MONOMER', 'PHET-MONOMER']
# PHOR-CPLX: ['PHOR-MONOMER']
# PHOSACETYLTRANS-CPLX: ['PHOSACETYLTRANS-MONOMER']
# PHOSGLYCMUTASE: ['GPMA-MONOMER']
# PHOSPHASERDECARB-DIMER: ['PHOSPHASERDECARB-BETA-MONOMER', 'PHOSPHASERDECARB-ALPHA-MONOMER']
# PII2-CPLX: ['PROTEIN-PII2']
# PIIPROTEIN-CPLX: ['PROTEIN-PII']
# PKI-COMPLEX: ['PKI-MONOMER']
# PKII-CPLX: ['PKII-MONOMER']
# PORPHOBILSYNTH-CPLX: ['PORPHOBILSYNTH-MONOMER']
# PPK-CPLX: ['PPK-MONOMER']
# PPPGPPHYDRO-CPLX: ['PPPGPPHYDRO-MONOMER']
# PPX-CPLX: ['PPX-MONOMER']
# PROS-CPLX: ['PROS-MONOMER']
# PRPPAMIDOTRANS-CPLX: ['PRPPAMIDOTRANS-MONOMER']
# PSERTRANSAM-CPLX: ['PSERTRANSAM-MONOMER']
# PURE-CPLX: ['PURE-MONOMER']
# PURK-CPLX: ['PURK-MONOMER']
# PUTA-CPLX: ['PUTA-MONOMER']
# PYRNUTRANSHYDROGEN-CPLX: ['PNTB-MONOMER', 'PNTA-MONOMER']
# PYRROLINECARBREDUCT-CPLX: ['PYRROLINECARBREDUCT-MONOMER']
# PYRUVATEDEH-CPLX: ['E1P-CPLX', 'E2P-MONOMER', 'E3-CPLX']
# PYRUVFORMLY-INACTIVE-CPLX: ['PYRUVFORMLY-MONOMER']
# PYRUVOXID-CPLX: ['PYRUVOXID-MONOMER']
# QOR-CPLX: ['QOR-MONOMER']
# QUINOPRIBOTRANS-CPLX: ['QUINOPRIBOTRANS-MONOMER']
# RECBCD: ['EG10826-MONOMER', 'EG10825-MONOMER', 'EG10824-MONOMER']
# RHAMNULPALDOL-CPLX: ['RHAMNULPALDOL-MONOMER']
# RIB5PISOMA-CPLX: ['RIB5PISOMA-MONOMER']
# RIB5PISOMB-CPLX: ['RIB5PISOMB-MONOMER']
# RIBONUCLEOSIDE-DIP-REDUCTI-CPLX: ['B1-CPLX', 'B2-CPLX']
# RIBONUCLEOSIDE-DIP-REDUCTII-CPLX: ['NRDE-CPLX', 'NRDF-CPLX']
# RIBONUCLEOSIDE-TRIP-REDUCT-CPLX: ['RIBONUCLEOSIDE-TRIP-REDUCT-MONOMER']
# RIBULOKIN-CPLX: ['RIBULOKIN-MONOMER']
# RIBULPEPIM-CPLX: ['RIBULPEPIM-MONOMER']
# RNAP32-CPLX: ['APORNAP-CPLX', 'RPOH-MONOMER']
# RNAP54-CPLX: ['APORNAP-CPLX', 'RPON-MONOMER']
# RNAP70-CPLX: ['APORNAP-CPLX', 'RPOD-MONOMER']
# RNAPE-CPLX: ['APORNAP-CPLX', 'RPOE-MONOMER']
# RNAPS-CPLX: ['APORNAP-CPLX', 'RPOS-MONOMER']
# RUVABC-CPLX: ['EG10925-MONOMER', 'EG10924-MONOMER', 'EG10923-MONOMER']
# S-ADENMETSYN-CPLX: ['S-ADENMETSYN-MONOMER']
# SAICARSYN-CPLX: ['SAICARSYN-MONOMER']
# SAMDECARB-CPLX: ['SAMDC-ALPHA-MONOMER', 'SAMDC-BETA-MONOMER']
# SEC-SECRETION-CPLX: []
# SECD-SECF-YAJC-YIDC-CPLX: []
# SECE-G-Y-CPLX: []
# SERS-CPLX: ['SERS-MONOMER']
# SIROHEMESYN-CPLX: ['SIROHEMESYN-MONOMER']
# SORB6PDEHYDROG-CPLX: ['SORB6PDEHYDROG-MONOMER']
# SPERMACTRAN-CPLX: ['SPERMACTRAN-MONOMER']
# SPERMIDINESYN-CPLX: ['SPERMIDINESYN-MONOMER']
# SUCC-DEHASE: ['SDH-FLAVO', 'SDH-FE-S', 'SDH-MEMB1', 'SDH-MEMB2']
# SUCCCOASYN: ['SUCCCOASYN-ALPHA', 'SUCCCOASYN-BETA']
# SUCCORNTRANSAM-CPLX: ['SUCCORNTRANSAM-MONOMER']
# SULFATE-ADENYLYLTRANS-CPLX: ['CYSD-MONOMER', 'CYSN-MONOMER']
# SULFITE-REDUCT-CPLX: ['CPLX0-7841', 'BETACOMP-MONOMER']
# SUPEROX-DISMUTFE-CPLX: ['SUPEROX-DISMUTFE-MONOMER']
# SUPEROX-DISMUTMN-CPLX: ['SUPEROX-DISMUTMN-MONOMER']
# TAP-CPLX: ['CHEA-CPLX', 'CHEW-MONOMER', 'CPLX0-8104']
# TAR-CPLX: ['CHEA-CPLX', 'CHEW-MONOMER', 'CPLX0-8102']
# TATABCE-CPLX: []
# THIOESTERII-CPLX: ['THIOESTERII-MONOMER']
# THIOREDOXIN-REDUCT-NADPH-CPLX: ['THIOREDOXIN-REDUCT-NADPH-MONOMER']
# THREDEHYDCAT-CPLX: ['THREDEHYDCAT-MONOMER']
# THREDEHYDSYN-CPLX: ['THREDEHYDSYN-MONOMER']
# THREODEHYD-CPLX: ['THREODEHYD-MONOMER']
# THRS-CPLX: ['THRS-MONOMER']
# THYMIDYLATESYN-CPLX: ['THYMIDYLATESYN-MONOMER']
# TMAOREDUCTI-CPLX: []
# TORR-CPLX: ['TORR-MONOMER']
# TORS-CPLX: ['TORS-MONOMER']
# TPI: ['TPI-MONOMER']
# TRANS-200-CPLX: ['CPLX0-7964', 'MACB', 'MACA']
# TRANS-CPLX-201: ['CPLX0-7964', 'EG11703-MONOMER', 'ACRB-MONOMER']
# TRANS-CPLX-202: ['CPLX0-7964', 'B2076-MONOMER', 'B2075-MONOMER', 'MDTA']
# TRANS-CPLX-203: ['EG12283-MONOMER', 'EG12282-MONOMER', 'MONOMER0-422']
# TRANS-CPLX-204: ['CPLX0-7964', 'EG12240-MONOMER', 'YHIV-MONOMER']
# TRANSALDOLB-CPLX: ['TRANSALDOLB-MONOMER']
# TRANSENOYLCOARED-CPLX: ['TRANSENOYLCOARED-MONOMER']
# TRANSKETOI-CPLX: ['TRANSKETOI-MONOMER']
# TRG-CPLX: ['CHEA-CPLX', 'CHEW-MONOMER', 'CPLX0-8105']
# TRPS-CPLX: ['TRPS-MONOMER']
# TRYPSYN: ['TRYPSYN-APROTEIN', 'CPLX0-2401']
# TRYPTOPHAN-CPLX: ['TRYPTOPHAN-MONOMER']
# TSR-CPLX: ['CHEW-MONOMER', 'CHEA-CPLX', 'CPLX0-8103']
# TYRB-DIMER: ['TYRB-MONOMER']
# TYRS-CPLX: ['TYRS-MONOMER']
# UDHA-CPLX: ['UDHA-MONOMER']
# UDPGLUCEPIM-CPLX: ['UDPGLUCEPIM-MONOMER']
# UDPNACETYLGLUCOSAMACYLTRANS-CPLX: ['UDPNACETYLGLUCOSAMACYLTRANS-MONOMER']
# UMPKI-CPLX: ['UMPKI-MONOMER']
# UPPSYN-CPLX: ['UPPSYN-MONOMER']
# URACIL-PRIBOSYLTRANS-CPLX: ['URACIL-PRIBOSYLTRANS-MONOMER']
# URPHOS-CPLX: ['URPHOS-MONOMER']
# UVRABC-CPLX: []
# XANTHOSINEPHOSPHORY-CPLX: ['XANTHOSINEPHOSPHORY-MONOMER']
# XYLISOM-CPLX: ['XYLISOM-MONOMER']
# YDGEF-CPLX: []
# CPLX0-10097: ['SRAJ-RNA', 'CPLX0-7998']
# CPLX0-10120: []
# CPLX0-1041: ['CSRB-RNA', 'EG11447-MONOMER']
# CPLX0-1382: ['RNPB-RNA', 'EG10862-MONOMER']
# CPLX0-3953: []
# CPLX0-3962: []
# CPLX0-3964: ['CPLX0-3953', 'CPLX0-3962']
# CPLX0-8028: []
# CPLX0-8053: []
# CPLX0-8253: ['CSRC-RNA', 'EG11447-MONOMER']
# SRP-CPLX: []

# %% [markdown]
# ## get expanded enzymes to gene products

# %%
# Initialize an empty list to hold both individual gene products and components of complexes
expanded_enzymes = []

for enzyme in unique_enzymes:
    # Check if the enzyme is a complex and has a mapping
    if enzyme in complex_to_components:
        # If it's a complex, extend the list with its components
        expanded_enzymes.extend(complex_to_components[enzyme])
    else:
        # If it's not a complex, just add the enzyme itself
        expanded_enzymes.append(enzyme)

# Remove duplicates by converting the list to a set, then back to a list
unique_gene_products = list(set(expanded_enzymes))

len(unique_gene_products)

# # Now, unique_gene_products contains only unique gene products, with complexes replaced by their components
# print(unique_gene_products)
# Out:
# 1746

# %% [markdown]
# ## analyze transcription/translation

# %%
genes
# Out:
#            id symbol                                           synonyms  \
# 0     EG10001    alr                ["alr", "alr5", "b4053", "ECK4045"]
# 1     EG10002   modB       ["modB", "chlJ", "tslJ", "b0764", "ECK0753"]
# 2     EG10003   cysZ                       ["cysZ", "b2413", "ECK2408"]
# 3     EG10004    dfp               ["dfp", "coaBC", "b3639", "ECK3629"]
# 4     EG10006   dcuB               ["dcuB", "genF", "b4123", "ECK4116"]
# ...       ...    ...                                                ...
# 4743     M013   mhpD               ["mhpD", "mhpS", "b0350", "ECK0347"]
# 4744     M014   mhpF                       ["mhpF", "b0351", "ECK0348"]
# 4745     M015   hcaF  ["hcaF", "yfhV", "hcaA", "phdC2", "digB", "hca...
# 4746     RUVA   ruvA                       ["ruvA", "b1861", "ECK1862"]
# 4747     RUVB   ruvB                       ["ruvB", "b1860", "ECK1861"]
#
#       left_end_pos  right_end_pos direction          rna_ids
# 0        4265782.0      4266861.0         +  ["EG10001_RNA"]
# 1         795862.0       796551.0         +  ["EG10002_RNA"]
# 2        2531463.0      2532224.0         +  ["EG10003_RNA"]
# 3        3812731.0      3813951.0         +  ["EG10004_RNA"]
# 4        4347404.0      4348744.0         -  ["EG10006_RNA"]
# ...            ...            ...       ...              ...
# 4743      372115.0       372924.0         +     ["M013_RNA"]
# 4744      372921.0       373871.0         +     ["M014_RNA"]
# 4745     2670390.0      2670908.0         +     ["M015_RNA"]
# 4746     1945365.0      1945976.0         -     ["RUVA_RNA"]
# 4747     1944346.0      1945356.0         -     ["RUVB_RNA"]
#
# [4748 rows x 7 columns]

# %%
transcripts
# Out:
#                id common_name  \
# 0     EG10001_RNA         alr
# 1     EG10002_RNA        modB
# 2     EG10003_RNA        cysZ
# 3     EG10004_RNA         dfp
# 4     EG10006_RNA        dcuB
# ...           ...         ...
# 4743     M013_RNA        mhpD
# 4744     M014_RNA        mhpF
# 4745     M015_RNA        hcaF
# 4746     RUVA_RNA        ruvA
# 4747     RUVB_RNA        ruvB
#
#                                                synonyms  type modified_forms  \
# 0                   ["alr", "alr5", "b4053", "ECK4045"]  mRNA             []
# 1          ["modB", "chlJ", "tslJ", "b0764", "ECK0753"]  mRNA             []
# 2                          ["cysZ", "b2413", "ECK2408"]  mRNA             []
# 3                  ["dfp", "coaBC", "b3639", "ECK3629"]  mRNA             []
# 4                  ["dcuB", "genF", "b4123", "ECK4116"]  mRNA             []
# ...                                                 ...   ...            ...
# 4743               ["mhpD", "mhpS", "b0350", "ECK0347"]  mRNA             []
# 4744                       ["mhpF", "b0351", "ECK0348"]  mRNA             []
# 4745  ["hcaF", "yfhV", "hcaA", "phdC2", "digB", "hca...  mRNA             []
# 4746                       ["ruvA", "b1861", "ECK1862"]  mRNA             []
# 4747                       ["ruvB", "b1860", "ECK1861"]  mRNA             []
#
#       gene_id              monomer_ids anticodon coding_segments
# 0     EG10001  [ALARACEBIOSYN-MONOMER]       NaN              []
# 1     EG10002           [MODB-MONOMER]       NaN              []
# 2     EG10003        [EG10003-MONOMER]       NaN              []
# 3     EG10004        [EG10004-MONOMER]       NaN              []
# 4     EG10006           [DCUB-MONOMER]       NaN              []
# ...       ...                      ...       ...             ...
# 4743     M013     [MHPDHYDROL-MONOMER]       NaN              []
# 4744     M014           [MHPF-MONOMER]       NaN              []
# 4745     M015          [HCAA2-MONOMER]       NaN              []
# 4746     RUVA        [EG10923-MONOMER]       NaN              []
# 4747     RUVB        [EG10924-MONOMER]       NaN              []
#
# [4748 rows x 9 columns]

# %%
# Create a mapping from gene IDs to RNA IDs
gene_to_rna_mapping = pd.Series(transcripts.id.values, index=transcripts.gene_id).to_dict()

# Create a mapping from RNA IDs to Monomer IDs
rna_to_monomer_mapping = pd.Series(transcripts.monomer_ids.values, index=transcripts.id).to_dict()

# Initialize an empty dictionary for the gene-to-monomer mapping
gene_to_monomer_mapping = {}

# Iterate through the gene_to_rna_mapping to populate the gene_to_monomer_mapping
for gene_id, rna_id in gene_to_rna_mapping.items():
    # Check if the RNA ID has a corresponding entry in the rna_to_monomer_mapping
    if rna_id in rna_to_monomer_mapping:
        # Add the mapping from gene ID to monomer IDs
        gene_to_monomer_mapping[gene_id] = rna_to_monomer_mapping[rna_id]

# Using a set to ensure uniqueness, and a list comprehension to flatten the list of lists
unique_monomers_set = {monomer for monomers_list in rna_to_monomer_mapping.values() for monomer in monomers_list}

# Convert the set back to a list if you need a list format
unique_monomers_list = list(unique_monomers_set)

len(unique_monomers_list)
# print(unique_monomers_list)
# print(gene_to_monomer_mapping)
# print(rna_to_monomer_mapping)
# print(gene_to_rna_mapping)
# Out:
# 4434
